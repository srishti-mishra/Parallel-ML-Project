# %%
from google.cloud import bigquery
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import matplotlib.patheffects as PathEffects
import matplotlib.pylab as pylab
import numpy as np
import pandas as pd
import itertools
from sklearn.metrics import  confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
import time
import seaborn as sns
from keras import utils, optimizers
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.losses import binary_crossentropy
# Out:
# Using TensorFlow backend.

# %%
miner_limit = 10000
non_miner_limit = 10000

# %%
# SQL query adapted from https://gist.github.com/allenday/16cf63fb6b3ed59b78903b2d414fe75b
sql = '''
WITH 
output_ages AS (
  SELECT
    ARRAY_TO_STRING(outputs.addresses,',') AS output_ages_address,
    MIN(block_timestamp_month) AS output_month_min,
    MAX(block_timestamp_month) AS output_month_max
  FROM `bigquery-public-data.crypto_bitcoin.transactions` AS transactions JOIN UNNEST(outputs) AS outputs
  GROUP BY output_ages_address
)
,input_ages AS (
  SELECT
    ARRAY_TO_STRING(inputs.addresses,',') AS input_ages_address,
    MIN(block_timestamp_month) AS input_month_min,
    MAX(block_timestamp_month) AS input_month_max
  FROM `bigquery-public-data.crypto_bitcoin.transactions` AS transactions JOIN UNNEST(inputs) AS inputs
  GROUP BY input_ages_address
)
,output_monthly_stats AS (
  SELECT
    ARRAY_TO_STRING(outputs.addresses,',') AS output_monthly_stats_address, 
    COUNT(DISTINCT block_timestamp_month) AS output_active_months,
    COUNT(outputs) AS total_tx_output_count,
    SUM(value) AS total_tx_output_value,
    AVG(value) AS mean_tx_output_value,
    STDDEV(value) AS stddev_tx_output_value,
    COUNT(DISTINCT(`hash`)) AS total_output_tx,
    SUM(value)/COUNT(block_timestamp_month) AS mean_monthly_output_value,
    COUNT(outputs.addresses)/COUNT(block_timestamp_month) AS mean_monthly_output_count
  FROM `bigquery-public-data.crypto_bitcoin.transactions` AS transactions JOIN UNNEST(outputs) AS outputs
  GROUP BY output_monthly_stats_address
)
,input_monthly_stats AS (
  SELECT
    ARRAY_TO_STRING(inputs.addresses,',') AS input_monthly_stats_address, 
    COUNT(DISTINCT block_timestamp_month) AS input_active_months,
    COUNT(inputs) AS total_tx_input_count,
    SUM(value) AS total_tx_input_value,
    AVG(value) AS mean_tx_input_value,
    STDDEV(value) AS stddev_tx_input_value,
    COUNT(DISTINCT(`hash`)) AS total_input_tx,
    SUM(value)/COUNT(block_timestamp_month) AS mean_monthly_input_value,
    COUNT(inputs.addresses)/COUNT(block_timestamp_month) AS mean_monthly_input_count
  FROM `bigquery-public-data.crypto_bitcoin.transactions` AS transactions JOIN UNNEST(inputs) AS inputs
  GROUP BY input_monthly_stats_address
)
,output_idle_times AS (
  SELECT
    address AS idle_time_address,
    AVG(idle_time) AS mean_output_idle_time,
    STDDEV(idle_time) AS stddev_output_idle_time
  FROM
  (
    SELECT 
      event.address,
      IF(prev_block_time IS NULL, NULL, UNIX_SECONDS(block_time) - UNIX_SECONDS(prev_block_time)) AS idle_time
    FROM (
      SELECT
        ARRAY_TO_STRING(outputs.addresses,',') AS address, 
        block_timestamp AS block_time,
        LAG(block_timestamp) OVER (PARTITION BY ARRAY_TO_STRING(outputs.addresses,',') ORDER BY block_timestamp) AS prev_block_time
      FROM `bigquery-public-data.crypto_bitcoin.transactions` AS transactions JOIN UNNEST(outputs) AS outputs
    ) AS event
    WHERE block_time != prev_block_time
  )
  GROUP BY address
)
,input_idle_times AS (
  SELECT
    address AS idle_time_address,
    AVG(idle_time) AS mean_input_idle_time,
    STDDEV(idle_time) AS stddev_input_idle_time
  FROM
  (
    SELECT 
      event.address,
      IF(prev_block_time IS NULL, NULL, UNIX_SECONDS(block_time) - UNIX_SECONDS(prev_block_time)) AS idle_time
    FROM (
      SELECT
        ARRAY_TO_STRING(inputs.addresses,',') AS address, 
        block_timestamp AS block_time,
        LAG(block_timestamp) OVER (PARTITION BY ARRAY_TO_STRING(inputs.addresses,',') ORDER BY block_timestamp) AS prev_block_time
      FROM `bigquery-public-data.crypto_bitcoin.transactions` AS transactions JOIN UNNEST(inputs) AS inputs
    ) AS event
    WHERE block_time != prev_block_time
  )
  GROUP BY address
)
--,miners AS (
--)

(SELECT
  TRUE AS is_miner,
  output_ages_address AS address,
  UNIX_SECONDS(CAST(output_ages.output_month_min AS TIMESTAMP)) AS output_month_min,
  UNIX_SECONDS(CAST(output_ages.output_month_max AS TIMESTAMP)) AS output_month_max,
  UNIX_SECONDS(CAST(input_ages.input_month_min AS TIMESTAMP)) AS input_month_min,
  UNIX_SECONDS(CAST(input_ages.input_month_max AS TIMESTAMP)) AS input_month_max,
  UNIX_SECONDS(CAST(output_ages.output_month_max AS TIMESTAMP)) - UNIX_SECONDS(CAST(output_ages.output_month_min AS TIMESTAMP)) AS output_active_time,
  UNIX_SECONDS(CAST(input_ages.input_month_max AS TIMESTAMP)) - UNIX_SECONDS(CAST(input_ages.input_month_min AS TIMESTAMP)) AS input_active_time,
  UNIX_SECONDS(CAST(output_ages.output_month_max AS TIMESTAMP)) - UNIX_SECONDS(CAST(input_ages.input_month_max AS TIMESTAMP)) AS io_max_lag,
  UNIX_SECONDS(CAST(output_ages.output_month_min AS TIMESTAMP)) - UNIX_SECONDS(CAST(input_ages.input_month_min AS TIMESTAMP)) AS io_min_lag,
  output_monthly_stats.output_active_months,
  output_monthly_stats.total_tx_output_count,
  output_monthly_stats.total_tx_output_value,
  output_monthly_stats.mean_tx_output_value,
  output_monthly_stats.stddev_tx_output_value,
  output_monthly_stats.total_output_tx,
  output_monthly_stats.mean_monthly_output_value,
  output_monthly_stats.mean_monthly_output_count,
  input_monthly_stats.input_active_months,
  input_monthly_stats.total_tx_input_count,
  input_monthly_stats.total_tx_input_value,
  input_monthly_stats.mean_tx_input_value,
  input_monthly_stats.stddev_tx_input_value,
  input_monthly_stats.total_input_tx,
  input_monthly_stats.mean_monthly_input_value,
  input_monthly_stats.mean_monthly_input_count,
  output_idle_times.mean_output_idle_time,
  output_idle_times.stddev_output_idle_time,
  input_idle_times.mean_input_idle_time,
  input_idle_times.stddev_input_idle_time
FROM
  output_ages, output_monthly_stats, output_idle_times,
  input_ages,  input_monthly_stats, input_idle_times
WHERE TRUE
  AND output_ages.output_ages_address = output_monthly_stats.output_monthly_stats_address
  AND output_ages.output_ages_address = output_idle_times.idle_time_address
  AND output_ages.output_ages_address = input_monthly_stats.input_monthly_stats_address
  AND output_ages.output_ages_address = input_ages.input_ages_address
  AND output_ages.output_ages_address = input_idle_times.idle_time_address
  AND output_ages.output_ages_address IN
(
  SELECT 
    ARRAY_TO_STRING(outputs.addresses,',') AS miner
  FROM 
  `bigquery-public-data.crypto_bitcoin.blocks` AS blocks,
  `bigquery-public-data.crypto_bitcoin.transactions` AS transactions JOIN UNNEST(outputs) AS outputs
  WHERE blocks.hash = transactions.block_hash 
    AND is_coinbase IS TRUE
    AND ( FALSE
      --
      -- miner signatures from https://en.bitcoin.it/wiki/Comparison_of_mining_pools
      --
      OR coinbase_param LIKE '%4d696e656420627920416e74506f6f6c%' --AntPool
      OR coinbase_param LIKE '%2f42434d6f6e737465722f%' --BCMonster
      --BitcoinAffiliateNetwork
      OR coinbase_param LIKE '%4269744d696e746572%' --BitMinter
      --BTC.com
      --BTCC Pool
      --BTCDig
      OR coinbase_param LIKE '%2f7374726174756d2f%' --Btcmp
      --btcZPool.com
      --BW Mining
      OR coinbase_param LIKE '%456c6967697573%' --Eligius
      --F2Pool
      --GHash.IO
      --Give Me COINS
      --Golden Nonce Pool
      OR coinbase_param LIKE '%2f627261766f2d6d696e696e672f%' --Bravo Mining
      OR coinbase_param LIKE '%4b616e6f%' --KanoPool
      --kmdPool.org
      OR coinbase_param LIKE '%2f6d6d706f6f6c%' --Merge Mining Pool
      --MergeMining
      --Multipool
      --P2Pool
      OR coinbase_param LIKE '%2f736c7573682f%' --Slush Pool
      --ZenPool.org
    )
  GROUP BY miner
  HAVING COUNT(1) >= 20 
)
LIMIT {})
UNION ALL
(SELECT
  FALSE AS is_miner,
  output_ages_address AS address,
  UNIX_SECONDS(CAST(output_ages.output_month_min AS TIMESTAMP)) AS output_month_min,
  UNIX_SECONDS(CAST(output_ages.output_month_max AS TIMESTAMP)) AS output_month_max,
  UNIX_SECONDS(CAST(input_ages.input_month_min AS TIMESTAMP)) AS input_month_min,
  UNIX_SECONDS(CAST(input_ages.input_month_max AS TIMESTAMP)) AS input_month_max,
  UNIX_SECONDS(CAST(output_ages.output_month_max AS TIMESTAMP)) - UNIX_SECONDS(CAST(output_ages.output_month_min AS TIMESTAMP)) AS output_active_time,
  UNIX_SECONDS(CAST(input_ages.input_month_max AS TIMESTAMP)) - UNIX_SECONDS(CAST(input_ages.input_month_min AS TIMESTAMP)) AS input_active_time,
  UNIX_SECONDS(CAST(output_ages.output_month_max AS TIMESTAMP)) - UNIX_SECONDS(CAST(input_ages.input_month_max AS TIMESTAMP)) AS io_max_lag,
  UNIX_SECONDS(CAST(output_ages.output_month_min AS TIMESTAMP)) - UNIX_SECONDS(CAST(input_ages.input_month_min AS TIMESTAMP)) AS io_min_lag,
  output_monthly_stats.output_active_months,
  output_monthly_stats.total_tx_output_count,
  output_monthly_stats.total_tx_output_value,
  output_monthly_stats.mean_tx_output_value,
  output_monthly_stats.stddev_tx_output_value,
  output_monthly_stats.total_output_tx,
  output_monthly_stats.mean_monthly_output_value,
  output_monthly_stats.mean_monthly_output_count,
  input_monthly_stats.input_active_months,
  input_monthly_stats.total_tx_input_count,
  input_monthly_stats.total_tx_input_value,
  input_monthly_stats.mean_tx_input_value,
  input_monthly_stats.stddev_tx_input_value,
  input_monthly_stats.total_input_tx,
  input_monthly_stats.mean_monthly_input_value,
  input_monthly_stats.mean_monthly_input_count,
  output_idle_times.mean_output_idle_time,
  output_idle_times.stddev_output_idle_time,
  input_idle_times.mean_input_idle_time,
  input_idle_times.stddev_input_idle_time
FROM
  output_ages, output_monthly_stats, output_idle_times,
  input_ages,  input_monthly_stats, input_idle_times
WHERE TRUE
  AND output_ages.output_ages_address = output_monthly_stats.output_monthly_stats_address
  AND output_ages.output_ages_address = output_idle_times.idle_time_address
  AND output_ages.output_ages_address = input_monthly_stats.input_monthly_stats_address
  AND output_ages.output_ages_address = input_ages.input_ages_address
  AND output_ages.output_ages_address = input_idle_times.idle_time_address
  AND output_ages.output_ages_address NOT IN
(
  SELECT 
    ARRAY_TO_STRING(outputs.addresses,',') AS miner
  FROM 
  `bigquery-public-data.crypto_bitcoin.blocks` AS blocks,
  `bigquery-public-data.crypto_bitcoin.transactions` AS transactions JOIN UNNEST(outputs) AS outputs
  WHERE blocks.hash = transactions.block_hash 
    AND is_coinbase IS TRUE
    AND ( FALSE
      --
      -- miner signatures from https://en.bitcoin.it/wiki/Comparison_of_mining_pools
      --
      OR coinbase_param LIKE '%4d696e656420627920416e74506f6f6c%' --AntPool
      OR coinbase_param LIKE '%2f42434d6f6e737465722f%' --BCMonster
      --BitcoinAffiliateNetwork
      OR coinbase_param LIKE '%4269744d696e746572%' --BitMinter
      --BTC.com
      --BTCC Pool
      --BTCDig
      OR coinbase_param LIKE '%2f7374726174756d2f%' --Btcmp
      --btcZPool.com
      --BW Mining
      OR coinbase_param LIKE '%456c6967697573%' --Eligius
      --F2Pool
      --GHash.IO
      --Give Me COINS
      --Golden Nonce Pool
      OR coinbase_param LIKE '%2f627261766f2d6d696e696e672f%' --Bravo Mining
      OR coinbase_param LIKE '%4b616e6f%' --KanoPool
      --kmdPool.org
      OR coinbase_param LIKE '%2f6d6d706f6f6c%' --Merge Mining Pool
      --MergeMining
      --Multipool
      --P2Pool
      OR coinbase_param LIKE '%2f736c7573682f%' --Slush Pool
      --ZenPool.org
    )
  GROUP BY miner
  HAVING COUNT(1) >= 20 
)
LIMIT {})
'''.format(miner_limit, non_miner_limit)

# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]=r"C:\Users\srish\Documents\NEU\Parallell ML and AI\Untitled Folder\json\My First Project-dd9334d0c0a8.json"
client = bigquery.Client()

# %%
time_start = time.time()
df = client.query(sql).to_dataframe()
print('Time elapsed: {} seconds' .format(time.time() - time_start))
# Out:
# Time elapsed: 217.58639121055603 seconds

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 30 columns):
# is_miner                     20000 non-null bool
# address                      20000 non-null object
# output_month_min             20000 non-null int64
# output_month_max             20000 non-null int64
# input_month_min              20000 non-null int64
# input_month_max              20000 non-null int64
# output_active_time           20000 non-null int64
# input_active_time            20000 non-null int64
# io_max_lag                   20000 non-null int64
# io_min_lag                   20000 non-null int64
# output_active_months         20000 non-null int64
# total_tx_output_count        20000 non-null int64
# total_tx_output_value        20000 non-null object
# mean_tx_output_value         20000 non-null object
# stddev_tx_output_value       20000 non-null float64
# total_output_tx              20000 non-null int64
# mean_monthly_output_value    20000 non-null object
# mean_monthly_output_count    20000 non-null float64
# input_active_months          20000 non-null int64
# total_tx_input_count         20000 non-null int64
# total_tx_input_value         20000 non-null object
# mean_tx_input_value          20000 non-null object
# stddev_tx_input_value        20000 non-null float64
# total_input_tx               20000 non-null int64
# mean_monthly_input_value     20000 non-null object
# mean_monthly_input_count     20000 non-null float64
# mean_output_idle_time        20000 non-null float64
# stddev_output_idle_time      16207 non-null float64
# mean_input_idle_time         20000 non-null float64
# stddev_input_idle_time       15242 non-null float64
# dtypes: bool(1), float64(8), int64(14), object(7)
# memory usage: 4.4+ MB

# %%
# Dropping the columns with null values
df.drop(labels = ['stddev_output_idle_time','stddev_input_idle_time'], axis = 1, inplace = True)

# %%
df.tail(5)
# Out:
#        is_miner                             address  output_month_min  \
# 19995      True  1LfpdXUwwjKWo14jip65stCtPx8uuFVD6M        1367366400
# 19996      True  16vEux5txgZmAjNnubiLiww73YjGoD1z2m        1406851200
# 19997      True  1Kk7qPuXBrPec6gMVG3Kb5LSdNy1sTxug4        1385856000
# 19998      True  1Nkt79pFX1UrRyfcizy4bu76mdzaAYaMmN        1383264000
# 19999      True  1GUjSF4ZEQmZAL6du6XntXdqQ9uR1mYkdi        1393632000
#
#        output_month_max  input_month_min  input_month_max  output_active_time  \
# 19995        1383264000       1372636800       1380585600            15897600
# 19996        1454284800       1414800000       1512086400            47433600
# 19997        1396310400       1396310400       1409529600            10454400
# 19998        1388534400       1383264000       1388534400             5270400
# 19999        1483228800       1393632000       1425168000            89596800
#
#        input_active_time  io_max_lag  io_min_lag  ...  input_active_months  \
# 19995            7948800     2678400    -5270400  ...                    3
# 19996           97286400   -57801600    -7948800  ...                    6
# 19997           13219200   -13219200   -10454400  ...                    4
# 19998            5270400           0           0  ...                    3
# 19999           31536000    58060800           0  ...                    9
#
#        total_tx_input_count total_tx_input_value mean_tx_input_value  \
# 19995                    44            767864999         17451477.25
# 19996                    43            175121718   4072598.093023256
# 19997                    45            207314621   4606991.577777778
# 19998                    45             72574466   1612765.911111111
# 19999                    44            280232160   6368912.727272727
#
#        stddev_tx_input_value  total_input_tx mean_monthly_input_value  \
# 19995           1.604927e+06               3              17451477.25
# 19996           1.140707e+06               9        4072598.093023256
# 19997           8.493911e+05               6        4606991.577777778
# 19998           9.891429e+05              26        1612765.911111111
# 19999           7.679995e+06              33        6368912.727272727
#
#        mean_monthly_input_count  mean_output_idle_time  mean_input_idle_time
# 19995                       1.0           3.827791e+05          4.632795e+06
# 19996                       1.0           1.074704e+06          1.234450e+07
# 19997                       1.0           2.290950e+05          2.263600e+06
# 19998                       1.0           1.224688e+05          2.178087e+05
# 19999                       1.0           1.997034e+06          9.776704e+05
#
# [5 rows x 28 columns]

# %%
df.head(5)
# Out:
#    is_miner                             address  output_month_min  \
# 0     False  3KsBM6BNwqSibdBbHR6cJpXSjiMB14jtUU        1514764800
# 1     False  32ok8QhsfsnzpYRAFbh4b12683Y77tyZiY        1464739200
# 2     False  1Ht1MAt6t6U9NBdXE4eM2wcvTsSpNtsnM5        1477958400
# 3     False  1GYJEU4mX33Fa9Wuw4Yc8ZZWFQ1wFVXr9s        1498867200
# 4     False  17ky7N2BPVm3iVT3cyebjzkMMeLSUgS2QJ        1541030400
#
#    output_month_max  input_month_min  input_month_max  output_active_time  \
# 0        1535760000       1514764800       1535760000            20995200
# 1        1472688000       1467331200       1530403200             7948800
# 2        1498867200       1477958400       1498867200            20908800
# 3        1506816000       1498867200       1506816000             7948800
# 4        1569888000       1543622400       1569888000            28857600
#
#    input_active_time  io_max_lag  io_min_lag  ...  input_active_months  \
# 0           20995200           0           0  ...                    9
# 1           63072000   -57715200    -2592000  ...                   10
# 2           20908800           0           0  ...                    8
# 3            7948800           0           0  ...                    3
# 4           26265600           0    -2592000  ...                   11
#
#    total_tx_input_count total_tx_input_value  mean_tx_input_value  \
# 0                    19             29979096    1577847.157894737
# 1                    20              8687876             434393.8
# 2                    19             16038019     844106.263157895
# 3                    11           1788306499  162573318.090909091
# 4                   173            276774337    1599851.658959538
#
#    stddev_tx_input_value  total_input_tx mean_monthly_input_value  \
# 0           5.178192e+05              19        1577847.157894737
# 1           2.685206e+05              20                 434393.8
# 2           5.104314e+05              19         844106.263157895
# 3           1.160758e+08              11      162573318.090909091
# 4           2.400947e+06             146        1599851.658959538
#
#    mean_monthly_input_count  mean_output_idle_time  mean_input_idle_time
# 0                       1.0           1.158474e+06          1.106894e+06
# 1                       1.0           5.197101e+05          3.234552e+06
# 2                       1.0           1.078961e+06          1.115924e+06
# 3                       1.0           5.392838e+05          7.549844e+05
# 4                       1.0           1.941717e+05          1.914987e+05
#
# [5 rows x 28 columns]

# %%
df.shape
# Out:
# (20000, 28)

# %%
# Dropping the non-numeric features
features = df.drop(labels = ['is_miner', 'address'], axis = 1)
target = df['is_miner'].values
indices = range(len(features))

# %%
sns.set_style('darkgrid')
sns.set_palette('muted')
sns.set_context("notebook", font_scale = 1.5, rc = {"lines.linewidth": 2.5})

# %%
def bitcoin_scatter(x, colors):
    # choose a color palette with seaborn.
    num_classes = len(np.unique(colors))
    palette = np.array(sns.color_palette("hls", num_classes))

    # create a scatter plot.
    f = plt.figure(figsize = (8, 8))
    ax = plt.subplot(aspect = 'equal')
    sc = ax.scatter(x[:,0], x[:,1], lw = 0, s = 40, c=palette[colors.astype(np.int)])
    plt.xlim(-25, 25)
    plt.ylim(-25, 25)
    ax.axis('off')
    ax.axis('tight')
    plt.title('t-SNE to visualize features')

    # add the labels for each digit corresponding to the label
    txts = []

    for i in range(num_classes):

        # Position of each label at median of data points.

        xtext, ytext = np.median(x[colors == i, :], axis = 0)
        txt = ax.text(xtext, ytext, str(i), fontsize = 24)
        txt.set_path_effects([
            PathEffects.Stroke(linewidth = 5, foreground = "w"),
            PathEffects.Normal()])
        txts.append(txt)

    return f, ax, sc, txts

# %%
time_start = time.time()
RS = 123
bitcoin_tsne = TSNE(random_state = RS).fit_transform(features)
print('Time elapsed: {} seconds' .format(time.time() - time_start))
# Out:
# Time elapsed: 245.62672805786133 seconds

# %%
bitcoin_scatter(bitcoin_tsne, target)
# Out:
# (<Figure size 576x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x2ed164c8c88>,
#  <matplotlib.collections.PathCollection at 0x2ed195b4048>,
#  [Text(-4.7729273, -30.686726, '0'), Text(4.4394693, 26.678068, '1')])

# %%
plt.savefig('tSNE1.jpg')

# %%
# Splitting the training and testing dataset
x_train, x_test, y_train, y_test, indices_train, indices_test = train_test_split(features, target, indices,  test_size = 0.2)

# %%
x_train.head()
# Out:
#       output_month_min  output_month_max  input_month_min  input_month_max  \
# 9020        1561939200        1564617600       1564617600       1564617600
# 3734        1391212800        1404172800       1393632000       1409529600
# 2551        1414800000        1483228800       1427846400       1459468800
# 1482        1388534400        1438387200       1388534400       1504224000
# 8518        1377993600        1438387200       1377993600       1446336000
#
#       output_active_time  input_active_time  io_max_lag  io_min_lag  \
# 9020             2678400                  0           0    -2678400
# 3734            12960000           15897600    -5356800    -2419200
# 2551            68428800           31622400    23760000   -13046400
# 1482            49852800          115689600   -65836800           0
# 8518            60393600           68342400    -7948800           0
#
#       output_active_months  total_tx_output_count  ... input_active_months  \
# 9020                     2                      2  ...                   1
# 3734                     6                     48  ...                   6
# 2551                    23                    186  ...                   3
# 1482                    12                    119  ...                   3
# 8518                     9                     89  ...                   7
#
#      total_tx_input_count  total_tx_input_value  mean_tx_input_value  \
# 9020                    2              24643959           12321979.5
# 3734                   48             339151833         7065663.1875
# 2551                  178            2215747225   12448018.117977528
# 1482                   13              52645573    4049659.461538462
# 8518                   89            5667191255   63676306.235955056
#
#      stddev_tx_input_value  total_input_tx  mean_monthly_input_value  \
# 9020          2.307446e+06               2                12321979.5
# 3734          3.832933e+06              27              7065663.1875
# 2551          2.141321e+07               8        12448018.117977528
# 1482          2.921068e+06               6         4049659.461538462
# 8518          1.668701e+08              17        63676306.235955056
#
#       mean_monthly_input_count mean_output_idle_time mean_input_idle_time
# 9020                       1.0         433917.000000         4.397100e+05
# 3734                       1.0         280803.659574         6.544084e+05
# 2551                       1.0         369801.021622         4.557543e+06
# 1482                       1.0         407571.135593         2.293463e+07
# 8518                       1.0         717049.395349         4.336956e+06
#
# [5 rows x 26 columns]

# %%
x_train.shape
# Out:
# (16000, 26)

# %%
y_train
# Out:
# array([False,  True,  True, ...,  True,  True, False])

# %%
# Feature Scaling
sc_x = StandardScaler()
x_train_ann = sc_x.fit_transform(x_train)
x_test_ann = sc_x.transform(x_test)

# %%
num_classes = 2

# Hyperparameters
learn_rate = 0.001
batch_size = 500
epochs = 270

# %%
# Encoding the Dependent Variable
labelencoder_y = LabelEncoder()
y_train_ann = labelencoder_y.fit_transform(y_train)

# Converting to binary class matrix
y_train_ann = utils.to_categorical(y_train_ann, num_classes)

# %%
y_train_ann.shape
# Out:
# (16000, 2)

# %%
# Encoding the Dependent Variable
labelencoder_y = LabelEncoder()
y_test_ann = labelencoder_y.fit_transform(y_test)

# Converting to binary class matrix
y_test_ann = utils.to_categorical(y_test_ann, num_classes)

# %%
y_test_ann.shape
# Out:
# (4000, 2)

# %%
seed = 1
np.random.seed(seed)

# Creating model
ann = Sequential()
ann.add(Dense(26, activation = 'tanh', kernel_initializer = 'glorot_uniform'))
ann.add(Dense(11, activation = 'tanh'))
ann.add(Dropout(0.5))
ann.add(Dense(6, activation = 'tanh'))
ann.add(Dense(num_classes, activation = 'softmax'))

# %%
rmsprop = optimizers.RMSprop(learn_rate)
ann.compile(loss = 'binary_crossentropy', optimizer = rmsprop, metrics = ['binary_accuracy']) # Compiling the model

# %%
# Model fitting
ann.fit(np.array(x_train_ann), y_train_ann, batch_size = batch_size, epochs = epochs, validation_data = (x_test_ann, y_test_ann))
# Out:
# Train on 16000 samples, validate on 4000 samples
# Epoch 1/270
# 16000/16000 [==============================] - 1s 48us/step - loss: 0.3892 - binary_accuracy: 0.8646 - val_loss: 0.2392 - val_binary_accuracy: 0.9350
# Epoch 2/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.2353 - binary_accuracy: 0.9354 - val_loss: 0.1769 - val_binary_accuracy: 0.9452
# Epoch 3/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.1832 - binary_accuracy: 0.9464 - val_loss: 0.1505 - val_binary_accuracy: 0.9492
# Epoch 4/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.1584 - binary_accuracy: 0.9508 - val_loss: 0.1354 - val_binary_accuracy: 0.9560
# Epoch 5/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.1415 - binary_accuracy: 0.9559 - val_loss: 0.1241 - val_binary_accuracy: 0.9590
# Epoch 6/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.1254 - binary_accuracy: 0.9590 - val_loss: 0.1113 - val_binary_accuracy: 0.9647
# Epoch 7/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.1159 - binary_accuracy: 0.9628 - val_loss: 0.1026 - val_binary_accuracy: 0.9697
# Epoch 8/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.1076 - binary_accuracy: 0.9675 - val_loss: 0.0941 - val_binary_accuracy: 0.9735
# Epoch 9/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0990 - binary_accuracy: 0.9707 - val_loss: 0.0859 - val_binary_accuracy: 0.9765
# Epoch 10/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0930 - binary_accuracy: 0.9732 - val_loss: 0.0796 - val_binary_accuracy: 0.9772
# Epoch 11/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0867 - binary_accuracy: 0.9741 - val_loss: 0.0760 - val_binary_accuracy: 0.9785
# Epoch 12/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0820 - binary_accuracy: 0.9769 - val_loss: 0.0724 - val_binary_accuracy: 0.9787
# Epoch 13/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0803 - binary_accuracy: 0.9769 - val_loss: 0.0709 - val_binary_accuracy: 0.9800
# Epoch 14/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0795 - binary_accuracy: 0.9778 - val_loss: 0.0696 - val_binary_accuracy: 0.9797
# Epoch 15/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0773 - binary_accuracy: 0.9774 - val_loss: 0.0684 - val_binary_accuracy: 0.9805
# Epoch 16/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0762 - binary_accuracy: 0.9783 - val_loss: 0.0679 - val_binary_accuracy: 0.9803
# Epoch 17/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0750 - binary_accuracy: 0.9794 - val_loss: 0.0673 - val_binary_accuracy: 0.9803
# Epoch 18/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0734 - binary_accuracy: 0.9794 - val_loss: 0.0659 - val_binary_accuracy: 0.9805
# Epoch 19/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0730 - binary_accuracy: 0.9795 - val_loss: 0.0655 - val_binary_accuracy: 0.9800
# Epoch 20/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0707 - binary_accuracy: 0.9800 - val_loss: 0.0687 - val_binary_accuracy: 0.9778
# Epoch 21/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0716 - binary_accuracy: 0.9808 - val_loss: 0.0643 - val_binary_accuracy: 0.9803
# Epoch 22/270
# 16000/16000 [==============================] - 0s 11us/step - loss: 0.0689 - binary_accuracy: 0.9804 - val_loss: 0.0638 - val_binary_accuracy: 0.9810
# Epoch 23/270
# 16000/16000 [==============================] - 0s 11us/step - loss: 0.0707 - binary_accuracy: 0.9802 - val_loss: 0.0640 - val_binary_accuracy: 0.9818
# Epoch 24/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0695 - binary_accuracy: 0.9811 - val_loss: 0.0623 - val_binary_accuracy: 0.9812
# Epoch 25/270
# 16000/16000 [==============================] - 0s 9us/step - loss: 0.0662 - binary_accuracy: 0.9804 - val_loss: 0.0624 - val_binary_accuracy: 0.9812
# Epoch 26/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0654 - binary_accuracy: 0.9808 - val_loss: 0.0618 - val_binary_accuracy: 0.9822
# Epoch 27/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0646 - binary_accuracy: 0.9816 - val_loss: 0.0617 - val_binary_accuracy: 0.9820
# Epoch 28/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0646 - binary_accuracy: 0.9830 - val_loss: 0.0606 - val_binary_accuracy: 0.9822
# Epoch 29/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0641 - binary_accuracy: 0.9820 - val_loss: 0.0594 - val_binary_accuracy: 0.9830
# Epoch 30/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0630 - binary_accuracy: 0.9824 - val_loss: 0.0586 - val_binary_accuracy: 0.9835
# Epoch 31/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0641 - binary_accuracy: 0.9824 - val_loss: 0.0592 - val_binary_accuracy: 0.9840
# Epoch 32/270
# 16000/16000 [==============================] - 0s 9us/step - loss: 0.0629 - binary_accuracy: 0.9822 - val_loss: 0.0589 - val_binary_accuracy: 0.9840
# Epoch 33/270
# 16000/16000 [==============================] - 0s 9us/step - loss: 0.0619 - binary_accuracy: 0.9827 - val_loss: 0.0583 - val_binary_accuracy: 0.9840
# Epoch 34/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0599 - binary_accuracy: 0.9829 - val_loss: 0.0591 - val_binary_accuracy: 0.9845
# Epoch 35/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0603 - binary_accuracy: 0.9826 - val_loss: 0.0582 - val_binary_accuracy: 0.9840
# Epoch 36/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0602 - binary_accuracy: 0.9833 - val_loss: 0.0583 - val_binary_accuracy: 0.9845
# Epoch 37/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0593 - binary_accuracy: 0.9839 - val_loss: 0.0574 - val_binary_accuracy: 0.9843
# Epoch 38/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0581 - binary_accuracy: 0.9836 - val_loss: 0.0575 - val_binary_accuracy: 0.9845
# Epoch 39/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0586 - binary_accuracy: 0.9833 - val_loss: 0.0587 - val_binary_accuracy: 0.9847
# Epoch 40/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0576 - binary_accuracy: 0.9833 - val_loss: 0.0574 - val_binary_accuracy: 0.9845
# Epoch 41/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0568 - binary_accuracy: 0.9841 - val_loss: 0.0562 - val_binary_accuracy: 0.9858
# Epoch 42/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0575 - binary_accuracy: 0.9835 - val_loss: 0.0575 - val_binary_accuracy: 0.9843
# Epoch 43/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0540 - binary_accuracy: 0.9846 - val_loss: 0.0576 - val_binary_accuracy: 0.9835
# Epoch 44/270
# 16000/16000 [==============================] - ETA: 0s - loss: 0.0555 - binary_accuracy: 0.985 - 0s 7us/step - loss: 0.0562 - binary_accuracy: 0.9849 - val_loss: 0.0555 - val_binary_accuracy: 0.9850
# Epoch 45/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0556 - binary_accuracy: 0.9844 - val_loss: 0.0562 - val_binary_accuracy: 0.9850
# Epoch 46/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0569 - binary_accuracy: 0.9832 - val_loss: 0.0558 - val_binary_accuracy: 0.9858
# Epoch 47/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0546 - binary_accuracy: 0.9844 - val_loss: 0.0555 - val_binary_accuracy: 0.9847
# Epoch 48/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0534 - binary_accuracy: 0.9856 - val_loss: 0.0551 - val_binary_accuracy: 0.9850
# Epoch 49/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0524 - binary_accuracy: 0.9849 - val_loss: 0.0552 - val_binary_accuracy: 0.9858
# Epoch 50/270
# 16000/16000 [==============================] - 0s 9us/step - loss: 0.0548 - binary_accuracy: 0.9849 - val_loss: 0.0576 - val_binary_accuracy: 0.9825
# Epoch 51/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0533 - binary_accuracy: 0.9851 - val_loss: 0.0554 - val_binary_accuracy: 0.9843
# Epoch 52/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0536 - binary_accuracy: 0.9844 - val_loss: 0.0567 - val_binary_accuracy: 0.9833
# Epoch 53/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0519 - binary_accuracy: 0.9856 - val_loss: 0.0562 - val_binary_accuracy: 0.9852
# Epoch 54/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0532 - binary_accuracy: 0.9853 - val_loss: 0.0573 - val_binary_accuracy: 0.9835
# Epoch 55/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0531 - binary_accuracy: 0.9852 - val_loss: 0.0549 - val_binary_accuracy: 0.9852
# Epoch 56/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0522 - binary_accuracy: 0.9851 - val_loss: 0.0554 - val_binary_accuracy: 0.9845
# Epoch 57/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0514 - binary_accuracy: 0.9846 - val_loss: 0.0554 - val_binary_accuracy: 0.9847
# Epoch 58/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0526 - binary_accuracy: 0.9852 - val_loss: 0.0551 - val_binary_accuracy: 0.9845
# Epoch 59/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0511 - binary_accuracy: 0.9858 - val_loss: 0.0560 - val_binary_accuracy: 0.9847
# Epoch 60/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0523 - binary_accuracy: 0.9854 - val_loss: 0.0553 - val_binary_accuracy: 0.9845
# Epoch 61/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0509 - binary_accuracy: 0.9856 - val_loss: 0.0568 - val_binary_accuracy: 0.9837
# Epoch 62/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0505 - binary_accuracy: 0.9852 - val_loss: 0.0561 - val_binary_accuracy: 0.9847
# Epoch 63/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0518 - binary_accuracy: 0.9856 - val_loss: 0.0560 - val_binary_accuracy: 0.9852
# Epoch 64/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0512 - binary_accuracy: 0.9853 - val_loss: 0.0551 - val_binary_accuracy: 0.9850
# Epoch 65/270
# 16000/16000 [==============================] - 0s 9us/step - loss: 0.0504 - binary_accuracy: 0.9864 - val_loss: 0.0563 - val_binary_accuracy: 0.9845
# Epoch 66/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0498 - binary_accuracy: 0.9863 - val_loss: 0.0545 - val_binary_accuracy: 0.9845
# Epoch 67/270
# 16000/16000 [==============================] - 0s 9us/step - loss: 0.0492 - binary_accuracy: 0.9869 - val_loss: 0.0557 - val_binary_accuracy: 0.9847
# Epoch 68/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0498 - binary_accuracy: 0.9856 - val_loss: 0.0554 - val_binary_accuracy: 0.9845
# Epoch 69/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0509 - binary_accuracy: 0.9852 - val_loss: 0.0565 - val_binary_accuracy: 0.9843
# Epoch 70/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0491 - binary_accuracy: 0.9864 - val_loss: 0.0558 - val_binary_accuracy: 0.9845
# Epoch 71/270
# 16000/16000 [==============================] - 0s 10us/step - loss: 0.0488 - binary_accuracy: 0.9861 - val_loss: 0.0553 - val_binary_accuracy: 0.9847
# Epoch 72/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0499 - binary_accuracy: 0.9861 - val_loss: 0.0562 - val_binary_accuracy: 0.9850
# Epoch 73/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0509 - binary_accuracy: 0.9861 - val_loss: 0.0563 - val_binary_accuracy: 0.9847
# Epoch 74/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0490 - binary_accuracy: 0.9864 - val_loss: 0.0561 - val_binary_accuracy: 0.9850
# Epoch 75/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0491 - binary_accuracy: 0.9860 - val_loss: 0.0546 - val_binary_accuracy: 0.9850
# Epoch 76/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0482 - binary_accuracy: 0.9871 - val_loss: 0.0553 - val_binary_accuracy: 0.9847
# Epoch 77/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0469 - binary_accuracy: 0.9872 - val_loss: 0.0546 - val_binary_accuracy: 0.9847
# Epoch 78/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0490 - binary_accuracy: 0.9862 - val_loss: 0.0579 - val_binary_accuracy: 0.9843
# Epoch 79/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0468 - binary_accuracy: 0.9868 - val_loss: 0.0572 - val_binary_accuracy: 0.9843
# Epoch 80/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0476 - binary_accuracy: 0.9866 - val_loss: 0.0561 - val_binary_accuracy: 0.9855
# Epoch 81/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0478 - binary_accuracy: 0.9866 - val_loss: 0.0555 - val_binary_accuracy: 0.9850
# Epoch 82/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0473 - binary_accuracy: 0.9877 - val_loss: 0.0572 - val_binary_accuracy: 0.9845
# Epoch 83/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0473 - binary_accuracy: 0.9861 - val_loss: 0.0544 - val_binary_accuracy: 0.9852
# Epoch 84/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0462 - binary_accuracy: 0.9876 - val_loss: 0.0558 - val_binary_accuracy: 0.9852
# Epoch 85/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0474 - binary_accuracy: 0.9871 - val_loss: 0.0569 - val_binary_accuracy: 0.9847
# Epoch 86/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0473 - binary_accuracy: 0.9877 - val_loss: 0.0559 - val_binary_accuracy: 0.9845
# Epoch 87/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0460 - binary_accuracy: 0.9873 - val_loss: 0.0564 - val_binary_accuracy: 0.9847
# Epoch 88/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0476 - binary_accuracy: 0.9863 - val_loss: 0.0589 - val_binary_accuracy: 0.9840
# Epoch 89/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0460 - binary_accuracy: 0.9869 - val_loss: 0.0564 - val_binary_accuracy: 0.9845
# Epoch 90/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0467 - binary_accuracy: 0.9868 - val_loss: 0.0585 - val_binary_accuracy: 0.9852
# Epoch 91/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0453 - binary_accuracy: 0.9874 - val_loss: 0.0551 - val_binary_accuracy: 0.9850
# Epoch 92/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0473 - binary_accuracy: 0.9872 - val_loss: 0.0611 - val_binary_accuracy: 0.9840
# Epoch 93/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0477 - binary_accuracy: 0.9866 - val_loss: 0.0546 - val_binary_accuracy: 0.9852
# Epoch 94/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0475 - binary_accuracy: 0.9875 - val_loss: 0.0566 - val_binary_accuracy: 0.9845
# Epoch 95/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0463 - binary_accuracy: 0.9874 - val_loss: 0.0539 - val_binary_accuracy: 0.9855
# Epoch 96/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0465 - binary_accuracy: 0.9875 - val_loss: 0.0573 - val_binary_accuracy: 0.9852
# Epoch 97/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0452 - binary_accuracy: 0.9872 - val_loss: 0.0557 - val_binary_accuracy: 0.9850
# Epoch 98/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0462 - binary_accuracy: 0.9875 - val_loss: 0.0609 - val_binary_accuracy: 0.9843
# Epoch 99/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0455 - binary_accuracy: 0.9874 - val_loss: 0.0569 - val_binary_accuracy: 0.9850
# Epoch 100/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0443 - binary_accuracy: 0.9874 - val_loss: 0.0558 - val_binary_accuracy: 0.9843
# Epoch 101/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0451 - binary_accuracy: 0.9872 - val_loss: 0.0561 - val_binary_accuracy: 0.9852
# Epoch 102/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0457 - binary_accuracy: 0.9871 - val_loss: 0.0557 - val_binary_accuracy: 0.9850
# Epoch 103/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0444 - binary_accuracy: 0.9878 - val_loss: 0.0588 - val_binary_accuracy: 0.9847
# Epoch 104/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0454 - binary_accuracy: 0.9868 - val_loss: 0.0557 - val_binary_accuracy: 0.9850
# Epoch 105/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0456 - binary_accuracy: 0.9872 - val_loss: 0.0585 - val_binary_accuracy: 0.9843
# Epoch 106/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0462 - binary_accuracy: 0.9876 - val_loss: 0.0598 - val_binary_accuracy: 0.9843
# Epoch 107/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0443 - binary_accuracy: 0.9880 - val_loss: 0.0588 - val_binary_accuracy: 0.9833
# Epoch 108/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0443 - binary_accuracy: 0.9874 - val_loss: 0.0547 - val_binary_accuracy: 0.9855
# Epoch 109/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0439 - binary_accuracy: 0.9882 - val_loss: 0.0557 - val_binary_accuracy: 0.9850
# Epoch 110/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0430 - binary_accuracy: 0.9878 - val_loss: 0.0566 - val_binary_accuracy: 0.9852
# Epoch 111/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0444 - binary_accuracy: 0.9877 - val_loss: 0.0563 - val_binary_accuracy: 0.9850
# Epoch 112/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0441 - binary_accuracy: 0.9877 - val_loss: 0.0553 - val_binary_accuracy: 0.9850
# Epoch 113/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0461 - binary_accuracy: 0.9877 - val_loss: 0.0557 - val_binary_accuracy: 0.9850
# Epoch 114/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0424 - binary_accuracy: 0.9883 - val_loss: 0.0553 - val_binary_accuracy: 0.9850
# Epoch 115/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0452 - binary_accuracy: 0.9876 - val_loss: 0.0565 - val_binary_accuracy: 0.9850
# Epoch 116/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0431 - binary_accuracy: 0.9881 - val_loss: 0.0545 - val_binary_accuracy: 0.9855
# Epoch 117/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0453 - binary_accuracy: 0.9872 - val_loss: 0.0577 - val_binary_accuracy: 0.9847
# Epoch 118/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0446 - binary_accuracy: 0.9881 - val_loss: 0.0579 - val_binary_accuracy: 0.9845
# Epoch 119/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0434 - binary_accuracy: 0.9885 - val_loss: 0.0565 - val_binary_accuracy: 0.9850
# Epoch 120/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0431 - binary_accuracy: 0.9885 - val_loss: 0.0555 - val_binary_accuracy: 0.9852
# Epoch 121/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0443 - binary_accuracy: 0.9883 - val_loss: 0.0558 - val_binary_accuracy: 0.9852
# Epoch 122/270
# 16000/16000 [==============================] - ETA: 0s - loss: 0.0410 - binary_accuracy: 0.989 - 0s 7us/step - loss: 0.0439 - binary_accuracy: 0.9879 - val_loss: 0.0542 - val_binary_accuracy: 0.9850
# Epoch 123/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0449 - binary_accuracy: 0.9872 - val_loss: 0.0536 - val_binary_accuracy: 0.9855
# Epoch 124/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0423 - binary_accuracy: 0.9883 - val_loss: 0.0548 - val_binary_accuracy: 0.9855
# Epoch 125/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0439 - binary_accuracy: 0.9883 - val_loss: 0.0558 - val_binary_accuracy: 0.9852
# Epoch 126/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0425 - binary_accuracy: 0.9884 - val_loss: 0.0586 - val_binary_accuracy: 0.9827
# Epoch 127/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0438 - binary_accuracy: 0.9879 - val_loss: 0.0552 - val_binary_accuracy: 0.9852
# Epoch 128/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0429 - binary_accuracy: 0.9879 - val_loss: 0.0578 - val_binary_accuracy: 0.9855
# Epoch 129/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0428 - binary_accuracy: 0.9887 - val_loss: 0.0559 - val_binary_accuracy: 0.9847
# Epoch 130/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0432 - binary_accuracy: 0.9880 - val_loss: 0.0578 - val_binary_accuracy: 0.9847
# Epoch 131/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0431 - binary_accuracy: 0.9874 - val_loss: 0.0566 - val_binary_accuracy: 0.9852
# Epoch 132/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0430 - binary_accuracy: 0.9881 - val_loss: 0.0558 - val_binary_accuracy: 0.9852
# Epoch 133/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0434 - binary_accuracy: 0.9877 - val_loss: 0.0574 - val_binary_accuracy: 0.9837
# Epoch 134/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0428 - binary_accuracy: 0.9886 - val_loss: 0.0590 - val_binary_accuracy: 0.9845
# Epoch 135/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0438 - binary_accuracy: 0.9872 - val_loss: 0.0557 - val_binary_accuracy: 0.9855
# Epoch 136/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0424 - binary_accuracy: 0.9886 - val_loss: 0.0563 - val_binary_accuracy: 0.9858
# Epoch 137/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0437 - binary_accuracy: 0.9883 - val_loss: 0.0545 - val_binary_accuracy: 0.9855
# Epoch 138/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0414 - binary_accuracy: 0.9886 - val_loss: 0.0563 - val_binary_accuracy: 0.9855
# Epoch 139/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0438 - binary_accuracy: 0.9880 - val_loss: 0.0542 - val_binary_accuracy: 0.9860
# Epoch 140/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0428 - binary_accuracy: 0.9881 - val_loss: 0.0577 - val_binary_accuracy: 0.9840
# Epoch 141/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0412 - binary_accuracy: 0.9886 - val_loss: 0.0569 - val_binary_accuracy: 0.9850
# Epoch 142/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0435 - binary_accuracy: 0.9884 - val_loss: 0.0582 - val_binary_accuracy: 0.9843
# Epoch 143/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0423 - binary_accuracy: 0.9879 - val_loss: 0.0574 - val_binary_accuracy: 0.9855
# Epoch 144/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0424 - binary_accuracy: 0.9884 - val_loss: 0.0550 - val_binary_accuracy: 0.9855
# Epoch 145/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0433 - binary_accuracy: 0.9881 - val_loss: 0.0552 - val_binary_accuracy: 0.9850
# Epoch 146/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0415 - binary_accuracy: 0.9886 - val_loss: 0.0564 - val_binary_accuracy: 0.9852
# Epoch 147/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0417 - binary_accuracy: 0.9886 - val_loss: 0.0559 - val_binary_accuracy: 0.9852
# Epoch 148/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0419 - binary_accuracy: 0.9877 - val_loss: 0.0552 - val_binary_accuracy: 0.9858
# Epoch 149/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0418 - binary_accuracy: 0.9886 - val_loss: 0.0563 - val_binary_accuracy: 0.9850
# Epoch 150/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0442 - binary_accuracy: 0.9883 - val_loss: 0.0560 - val_binary_accuracy: 0.9845
# Epoch 151/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0412 - binary_accuracy: 0.9883 - val_loss: 0.0568 - val_binary_accuracy: 0.9850
# Epoch 152/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0429 - binary_accuracy: 0.9877 - val_loss: 0.0551 - val_binary_accuracy: 0.9858
# Epoch 153/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0426 - binary_accuracy: 0.9881 - val_loss: 0.0548 - val_binary_accuracy: 0.9855
# Epoch 154/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0407 - binary_accuracy: 0.9887 - val_loss: 0.0610 - val_binary_accuracy: 0.9837
# Epoch 155/270
# 16000/16000 [==============================] - 0s 10us/step - loss: 0.0427 - binary_accuracy: 0.9876 - val_loss: 0.0554 - val_binary_accuracy: 0.9858
# Epoch 156/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0411 - binary_accuracy: 0.9885 - val_loss: 0.0537 - val_binary_accuracy: 0.9858
# Epoch 157/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0407 - binary_accuracy: 0.9887 - val_loss: 0.0557 - val_binary_accuracy: 0.9847
# Epoch 158/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0427 - binary_accuracy: 0.9876 - val_loss: 0.0573 - val_binary_accuracy: 0.9852
# Epoch 159/270
# 16000/16000 [==============================] - 0s 9us/step - loss: 0.0419 - binary_accuracy: 0.9884 - val_loss: 0.0568 - val_binary_accuracy: 0.9850
# Epoch 160/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0418 - binary_accuracy: 0.9882 - val_loss: 0.0547 - val_binary_accuracy: 0.9858
# Epoch 161/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0420 - binary_accuracy: 0.9878 - val_loss: 0.0561 - val_binary_accuracy: 0.9852
# Epoch 162/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0414 - binary_accuracy: 0.9881 - val_loss: 0.0571 - val_binary_accuracy: 0.9855
# Epoch 163/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0411 - binary_accuracy: 0.9888 - val_loss: 0.0572 - val_binary_accuracy: 0.9860
# Epoch 164/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0418 - binary_accuracy: 0.9880 - val_loss: 0.0538 - val_binary_accuracy: 0.9865
# Epoch 165/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0410 - binary_accuracy: 0.9888 - val_loss: 0.0540 - val_binary_accuracy: 0.9852
# Epoch 166/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0428 - binary_accuracy: 0.9884 - val_loss: 0.0548 - val_binary_accuracy: 0.9855
# Epoch 167/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0425 - binary_accuracy: 0.9881 - val_loss: 0.0540 - val_binary_accuracy: 0.9855
# Epoch 168/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0412 - binary_accuracy: 0.9890 - val_loss: 0.0548 - val_binary_accuracy: 0.9858
# Epoch 169/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0415 - binary_accuracy: 0.9882 - val_loss: 0.0573 - val_binary_accuracy: 0.9852
# Epoch 170/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0416 - binary_accuracy: 0.9879 - val_loss: 0.0560 - val_binary_accuracy: 0.9855
# Epoch 171/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0424 - binary_accuracy: 0.9887 - val_loss: 0.0563 - val_binary_accuracy: 0.9855
# Epoch 172/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0394 - binary_accuracy: 0.9883 - val_loss: 0.0548 - val_binary_accuracy: 0.9860
# Epoch 173/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0421 - binary_accuracy: 0.9880 - val_loss: 0.0560 - val_binary_accuracy: 0.9852
# Epoch 174/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0413 - binary_accuracy: 0.9883 - val_loss: 0.0549 - val_binary_accuracy: 0.9860
# Epoch 175/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0409 - binary_accuracy: 0.9883 - val_loss: 0.0549 - val_binary_accuracy: 0.9860
# Epoch 176/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0415 - binary_accuracy: 0.9885 - val_loss: 0.0547 - val_binary_accuracy: 0.9860
# Epoch 177/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0403 - binary_accuracy: 0.9889 - val_loss: 0.0582 - val_binary_accuracy: 0.9855
# Epoch 178/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0424 - binary_accuracy: 0.9880 - val_loss: 0.0555 - val_binary_accuracy: 0.9855
# Epoch 179/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0396 - binary_accuracy: 0.9892 - val_loss: 0.0553 - val_binary_accuracy: 0.9862
# Epoch 180/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0405 - binary_accuracy: 0.9887 - val_loss: 0.0568 - val_binary_accuracy: 0.9858
# Epoch 181/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0411 - binary_accuracy: 0.9880 - val_loss: 0.0564 - val_binary_accuracy: 0.9858
# Epoch 182/270
# 16000/16000 [==============================] - 0s 9us/step - loss: 0.0402 - binary_accuracy: 0.9891 - val_loss: 0.0559 - val_binary_accuracy: 0.9860
# Epoch 183/270
# 16000/16000 [==============================] - 0s 9us/step - loss: 0.0412 - binary_accuracy: 0.9880 - val_loss: 0.0559 - val_binary_accuracy: 0.9865
# Epoch 184/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0399 - binary_accuracy: 0.9889 - val_loss: 0.0534 - val_binary_accuracy: 0.9862
# Epoch 185/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0401 - binary_accuracy: 0.9889 - val_loss: 0.0553 - val_binary_accuracy: 0.9860
# Epoch 186/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0430 - binary_accuracy: 0.9883 - val_loss: 0.0535 - val_binary_accuracy: 0.9860
# Epoch 187/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0394 - binary_accuracy: 0.9888 - val_loss: 0.0600 - val_binary_accuracy: 0.9852
# Epoch 188/270
# 16000/16000 [==============================] - 0s 10us/step - loss: 0.0415 - binary_accuracy: 0.9885 - val_loss: 0.0539 - val_binary_accuracy: 0.9858
# Epoch 189/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0403 - binary_accuracy: 0.9888 - val_loss: 0.0558 - val_binary_accuracy: 0.9860
# Epoch 190/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0402 - binary_accuracy: 0.9885 - val_loss: 0.0560 - val_binary_accuracy: 0.9858
# Epoch 191/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0410 - binary_accuracy: 0.9889 - val_loss: 0.0561 - val_binary_accuracy: 0.9860
# Epoch 192/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0405 - binary_accuracy: 0.9890 - val_loss: 0.0565 - val_binary_accuracy: 0.9860
# Epoch 193/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0407 - binary_accuracy: 0.9887 - val_loss: 0.0549 - val_binary_accuracy: 0.9865
# Epoch 194/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0388 - binary_accuracy: 0.9891 - val_loss: 0.0539 - val_binary_accuracy: 0.9868
# Epoch 195/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0404 - binary_accuracy: 0.9888 - val_loss: 0.0546 - val_binary_accuracy: 0.9860
# Epoch 196/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0400 - binary_accuracy: 0.9896 - val_loss: 0.0582 - val_binary_accuracy: 0.9845
# Epoch 197/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0406 - binary_accuracy: 0.9894 - val_loss: 0.0545 - val_binary_accuracy: 0.9865
# Epoch 198/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0413 - binary_accuracy: 0.9891 - val_loss: 0.0563 - val_binary_accuracy: 0.9860
# Epoch 199/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0392 - binary_accuracy: 0.9891 - val_loss: 0.0560 - val_binary_accuracy: 0.9858
# Epoch 200/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0399 - binary_accuracy: 0.9889 - val_loss: 0.0569 - val_binary_accuracy: 0.9850
# Epoch 201/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0393 - binary_accuracy: 0.9883 - val_loss: 0.0542 - val_binary_accuracy: 0.9860
# Epoch 202/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0403 - binary_accuracy: 0.9889 - val_loss: 0.0534 - val_binary_accuracy: 0.9862
# Epoch 203/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0420 - binary_accuracy: 0.9887 - val_loss: 0.0542 - val_binary_accuracy: 0.9858
# Epoch 204/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0394 - binary_accuracy: 0.9895 - val_loss: 0.0563 - val_binary_accuracy: 0.9850
# Epoch 205/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0392 - binary_accuracy: 0.9891 - val_loss: 0.0545 - val_binary_accuracy: 0.9860
# Epoch 206/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0397 - binary_accuracy: 0.9892 - val_loss: 0.0555 - val_binary_accuracy: 0.9858
# Epoch 207/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0398 - binary_accuracy: 0.9890 - val_loss: 0.0554 - val_binary_accuracy: 0.9860
# Epoch 208/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0399 - binary_accuracy: 0.9890 - val_loss: 0.0548 - val_binary_accuracy: 0.9858
# Epoch 209/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0395 - binary_accuracy: 0.9890 - val_loss: 0.0556 - val_binary_accuracy: 0.9855
# Epoch 210/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0403 - binary_accuracy: 0.9886 - val_loss: 0.0552 - val_binary_accuracy: 0.9858
# Epoch 211/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0397 - binary_accuracy: 0.9886 - val_loss: 0.0561 - val_binary_accuracy: 0.9858
# Epoch 212/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0406 - binary_accuracy: 0.9893 - val_loss: 0.0556 - val_binary_accuracy: 0.9860
# Epoch 213/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0388 - binary_accuracy: 0.9889 - val_loss: 0.0557 - val_binary_accuracy: 0.9858
# Epoch 214/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0407 - binary_accuracy: 0.9891 - val_loss: 0.0539 - val_binary_accuracy: 0.9855
# Epoch 215/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0406 - binary_accuracy: 0.9886 - val_loss: 0.0539 - val_binary_accuracy: 0.9868
# Epoch 216/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0402 - binary_accuracy: 0.9888 - val_loss: 0.0545 - val_binary_accuracy: 0.9865
# Epoch 217/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0383 - binary_accuracy: 0.9896 - val_loss: 0.0563 - val_binary_accuracy: 0.9862
# Epoch 218/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0393 - binary_accuracy: 0.9895 - val_loss: 0.0552 - val_binary_accuracy: 0.9862
# Epoch 219/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0397 - binary_accuracy: 0.9892 - val_loss: 0.0538 - val_binary_accuracy: 0.9860
# Epoch 220/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0385 - binary_accuracy: 0.9902 - val_loss: 0.0550 - val_binary_accuracy: 0.9855
# Epoch 221/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0415 - binary_accuracy: 0.9884 - val_loss: 0.0523 - val_binary_accuracy: 0.9865
# Epoch 222/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0394 - binary_accuracy: 0.9885 - val_loss: 0.0530 - val_binary_accuracy: 0.9860
# Epoch 223/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0394 - binary_accuracy: 0.9891 - val_loss: 0.0547 - val_binary_accuracy: 0.9855
# Epoch 224/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0394 - binary_accuracy: 0.9886 - val_loss: 0.0542 - val_binary_accuracy: 0.9862
# Epoch 225/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0409 - binary_accuracy: 0.9892 - val_loss: 0.0537 - val_binary_accuracy: 0.9865
# Epoch 226/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0399 - binary_accuracy: 0.9890 - val_loss: 0.0520 - val_binary_accuracy: 0.9860
# Epoch 227/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0388 - binary_accuracy: 0.9899 - val_loss: 0.0537 - val_binary_accuracy: 0.9862
# Epoch 228/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0397 - binary_accuracy: 0.9887 - val_loss: 0.0558 - val_binary_accuracy: 0.9855
# Epoch 229/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0398 - binary_accuracy: 0.9887 - val_loss: 0.0520 - val_binary_accuracy: 0.9862
# Epoch 230/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0414 - binary_accuracy: 0.9887 - val_loss: 0.0534 - val_binary_accuracy: 0.9860
# Epoch 231/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0389 - binary_accuracy: 0.9893 - val_loss: 0.0531 - val_binary_accuracy: 0.9860
# Epoch 232/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0382 - binary_accuracy: 0.9889 - val_loss: 0.0533 - val_binary_accuracy: 0.9860
# Epoch 233/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0385 - binary_accuracy: 0.9891 - val_loss: 0.0542 - val_binary_accuracy: 0.9865
# Epoch 234/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0389 - binary_accuracy: 0.9891 - val_loss: 0.0532 - val_binary_accuracy: 0.9865
# Epoch 235/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0406 - binary_accuracy: 0.9887 - val_loss: 0.0533 - val_binary_accuracy: 0.9858
# Epoch 236/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0399 - binary_accuracy: 0.9896 - val_loss: 0.0522 - val_binary_accuracy: 0.9868
# Epoch 237/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0396 - binary_accuracy: 0.9887 - val_loss: 0.0515 - val_binary_accuracy: 0.9877
# Epoch 238/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0404 - binary_accuracy: 0.9884 - val_loss: 0.0541 - val_binary_accuracy: 0.9862
# Epoch 239/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0394 - binary_accuracy: 0.9889 - val_loss: 0.0517 - val_binary_accuracy: 0.9858
# Epoch 240/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0405 - binary_accuracy: 0.9890 - val_loss: 0.0551 - val_binary_accuracy: 0.9860
# Epoch 241/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0391 - binary_accuracy: 0.9893 - val_loss: 0.0532 - val_binary_accuracy: 0.9860
# Epoch 242/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0401 - binary_accuracy: 0.9891 - val_loss: 0.0524 - val_binary_accuracy: 0.9860
# Epoch 243/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0404 - binary_accuracy: 0.9881 - val_loss: 0.0516 - val_binary_accuracy: 0.9865
# Epoch 244/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0396 - binary_accuracy: 0.9892 - val_loss: 0.0507 - val_binary_accuracy: 0.9862
# Epoch 245/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0392 - binary_accuracy: 0.9893 - val_loss: 0.0554 - val_binary_accuracy: 0.9868
# Epoch 246/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0387 - binary_accuracy: 0.9893 - val_loss: 0.0522 - val_binary_accuracy: 0.9862
# Epoch 247/270
# 16000/16000 [==============================] - 0s 13us/step - loss: 0.0394 - binary_accuracy: 0.9891 - val_loss: 0.0508 - val_binary_accuracy: 0.9868
# Epoch 248/270
# 16000/16000 [==============================] - 0s 9us/step - loss: 0.0381 - binary_accuracy: 0.9897 - val_loss: 0.0530 - val_binary_accuracy: 0.9860
# Epoch 249/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0388 - binary_accuracy: 0.9895 - val_loss: 0.0549 - val_binary_accuracy: 0.9850
# Epoch 250/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0399 - binary_accuracy: 0.9893 - val_loss: 0.0583 - val_binary_accuracy: 0.9845
# Epoch 251/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0391 - binary_accuracy: 0.9892 - val_loss: 0.0541 - val_binary_accuracy: 0.9855
# Epoch 252/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0386 - binary_accuracy: 0.9891 - val_loss: 0.0535 - val_binary_accuracy: 0.9855
# Epoch 253/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0387 - binary_accuracy: 0.9893 - val_loss: 0.0527 - val_binary_accuracy: 0.9868
# Epoch 254/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0383 - binary_accuracy: 0.9893 - val_loss: 0.0507 - val_binary_accuracy: 0.9862
# Epoch 255/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0392 - binary_accuracy: 0.9890 - val_loss: 0.0537 - val_binary_accuracy: 0.9865
# Epoch 256/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0389 - binary_accuracy: 0.9895 - val_loss: 0.0536 - val_binary_accuracy: 0.9858
# Epoch 257/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0389 - binary_accuracy: 0.9889 - val_loss: 0.0553 - val_binary_accuracy: 0.9865
# Epoch 258/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0391 - binary_accuracy: 0.9891 - val_loss: 0.0554 - val_binary_accuracy: 0.9860
# Epoch 259/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0385 - binary_accuracy: 0.9885 - val_loss: 0.0530 - val_binary_accuracy: 0.9870
# Epoch 260/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0395 - binary_accuracy: 0.9892 - val_loss: 0.0537 - val_binary_accuracy: 0.9865
# Epoch 261/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0370 - binary_accuracy: 0.9901 - val_loss: 0.0527 - val_binary_accuracy: 0.9865
# Epoch 262/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0401 - binary_accuracy: 0.9880 - val_loss: 0.0536 - val_binary_accuracy: 0.9862
# Epoch 263/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0384 - binary_accuracy: 0.9899 - val_loss: 0.0585 - val_binary_accuracy: 0.9852
# Epoch 264/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0387 - binary_accuracy: 0.9894 - val_loss: 0.0523 - val_binary_accuracy: 0.9862
# Epoch 265/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0394 - binary_accuracy: 0.9891 - val_loss: 0.0565 - val_binary_accuracy: 0.9843
# Epoch 266/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0386 - binary_accuracy: 0.9894 - val_loss: 0.0569 - val_binary_accuracy: 0.9845
# Epoch 267/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0395 - binary_accuracy: 0.9888 - val_loss: 0.0529 - val_binary_accuracy: 0.9865
# Epoch 268/270
# 16000/16000 [==============================] - 0s 8us/step - loss: 0.0381 - binary_accuracy: 0.9893 - val_loss: 0.0518 - val_binary_accuracy: 0.9858
# Epoch 269/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0385 - binary_accuracy: 0.9899 - val_loss: 0.0520 - val_binary_accuracy: 0.9865
# Epoch 270/270
# 16000/16000 [==============================] - 0s 7us/step - loss: 0.0372 - binary_accuracy: 0.9902 - val_loss: 0.0550 - val_binary_accuracy: 0.9862

# %%
ann.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 26)                702
# _________________________________________________________________
# dense_2 (Dense)              (None, 11)                297
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 11)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 72
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 14
# =================================================================
# Total params: 1,085
# Trainable params: 1,085
# Non-trainable params: 0
# _________________________________________________________________

# %%
scores = ann.evaluate(x_test_ann, y_test_ann, verbose = 0)
print("Test Accuracy (Artificial Neural Network): {}%" .format(scores[1] * 100))
# Out:
# Test Accuracy (Artificial Neural Network): 98.62499833106995%

# %%
scores
# Out:
# [0.05496803922392428, 0.9862499833106995]

# %%
y_pred = ann.predict(x_test_ann)

# Compute confusion matrix
matrix = confusion_matrix(y_test_ann.argmax(axis = 1), y_pred.argmax(axis = 1)) # Building the confusion matrix

# %%
matrix
# Out:
# array([[1950,   39],
#        [  16, 1995]], dtype=int64)

# %%
# Training the model
rf = RandomForestClassifier(n_estimators = 100, class_weight = 'balanced')
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight='balanced',
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=None, oob_score=False,
#                        random_state=None, verbose=0, warm_start=False)

# %%
# Model predictions
y_pred = rf.predict(x_test)
probs = rf.predict_proba(x_test)[:, 1] # Positive class probabilities

# %%
params = {'legend.fontsize': 'small',
         'axes.labelsize': 'x-small',
         'axes.titlesize':'small',
         'xtick.labelsize':'x-small',
         'ytick.labelsize':'x-small'}
pylab.rcParams.update(params)

# %%
# Confusion matrix code adapted from https://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
def plot_confusion_matrix(cm, classes, normalize = False, title = 'Confusion matrix', cmap = plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize = True.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis = 1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    dummy = np.array([[0, 0], [0, 0]])
    plt.figure(figsize = (6, 6))
    plt.imshow(dummy, interpolation = 'nearest', cmap = cmap)
    plt.title(title)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation = 45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment = "center",
                 color = "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()


# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
class_names = ['not mining pool', 'mining pool']
np.set_printoptions(precision = 2)

# Plot confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes = class_names, normalize = False, title = 'Bitcoin Mining Pool Detector using Random Forest - Confusion Matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[1960   29]
#  [  10 2001]]

# %%
# Calculating Accuracy
acc = (cnf_matrix[0][0] + cnf_matrix[1][1]) / (cnf_matrix[0][0] + cnf_matrix[1][1] + cnf_matrix[0][1] + cnf_matrix[1][0])

# %%
print("Test Accuracy (Random Forest Classification): {}%" .format(acc * 100))
# Out:
# Test Accuracy (Random Forest Classification): 99.02499999999999%

# %%
params = {'legend.fontsize': 'small',
         'axes.labelsize': 'small',
         'axes.titlesize':'small',
         'xtick.labelsize':'small',
         'ytick.labelsize':'small'
         }
pylab.rcParams.update(params)

# %%
x_pos = np.arange(len(features.columns))
btc_importances = rf.feature_importances_

inds = np.argsort(btc_importances)[::-1]
btc_importances = btc_importances[inds]
cols = features.columns[inds]
bar_width = .8

# How many features to plot?
n_features = 26
x_pos = x_pos[:n_features][::-1]
btc_importances = btc_importances[:n_features]

# Plot
plt.figure(figsize = (26, 10))
plt.barh(x_pos, btc_importances, bar_width, label = 'BTC model')
plt.yticks(x_pos, cols, rotation = 0, fontsize = 14)
plt.xlabel('feature importance', fontsize = 14)
plt.title('Mining Pool Detector', fontsize = 20)
plt.tight_layout()

# %%
# Data points where model predicts true, but are labelled as false
false_positives = (y_test == False) & (y_pred == True)

# %%
# Subset to test set data only
df_test = df.iloc[indices_test, :]

print('False Positive addresses')

# Subset test set to false positives only
df_test.iloc[false_positives].head(15)
# Out:
# False Positive addresses
#        is_miner                             address  output_month_min  \
# 454       False  1P6mGQ9bWoPstkGVAvRJowkJ3vjfBX55Ks        1317427200
# 17477     False  1Ce9xiZPaQV52nEn72vvNDtiDZsoAh21wt        1401580800
# 18523     False  14jqy419bBfinFTqyeSp6NiLGqEVcJgJ5b        1393632000
# 245       False  1NYMc7TRTTotamHdibCpHayafvD9RXU4JP        1301616000
# 19022     False  1Dwh7VrVyR1okMvaVxj4syX4hBFsXRrfsS        1443657600
# 18274     False  18pn7Fis3zMetmJAAdXWc6uDfqeqvTEDtJ        1438387200
# 221       False  12g5w3t2gHpQhTngumAp2REKrdtxyNthW1        1420070400
# 972       False  3J4u9J21zkSwcz8rUkrPNhSq3x5grc1KpC        1443657600
# 18884     False  1FcvfQs5D4KjBNetkRVjyy4kSUhx8NKjfG        1435708800
# 395       False  128gLEQjx6o9pxjpsSxptBn6UoxEbjWsu2        1446336000
# 640       False  182ieLms9AcP76JpA9asDVL5wyHkk3iidT        1385856000
# 756       False  1P7EbB5GVJWdfBrVnC2Qx4noGKnYa9Aeao        1427846400
# 443       False   195Q8fV4roL1KQAuyNvHBpSyWs2CubLve        1362096000
# 17730     False  17cy2W6GihxBaVZuxaDWYgYcdbeWK1g5mh        1441065600
# 179       False  1D7m94SE6tk5aNZtUen69vDeK7Wi9Y1yrX        1404172800
#
#        output_month_max  input_month_min  input_month_max  output_active_time  \
# 454          1519862400       1343779200       1522540800           202435200
# 17477        1406851200       1401580800       1406851200             5270400
# 18523        1422748800       1393632000       1422748800            29116800
# 245          1362096000       1304208000       1362096000            60480000
# 19022        1459468800       1443657600       1459468800            15811200
# 18274        1443657600       1438387200       1443657600             5270400
# 221          1454284800       1422748800       1454284800            34214400
# 972          1522540800       1493596800       1525132800            78883200
# 18884        1546300800       1435708800       1551398400           110592000
# 395          1464739200       1446336000       1464739200            18403200
# 640          1393632000       1385856000       1393632000             7776000
# 756          1443657600       1427846400       1443657600            15811200
# 443          1433116800       1362096000       1380585600            71020800
# 17730        1462060800       1441065600       1462060800            20995200
# 179          1422748800       1404172800       1422748800            18576000
#
#        input_active_time  io_max_lag  io_min_lag  ...  input_active_months  \
# 454            178761600    -2678400   -26352000  ...                    5
# 17477            5270400           0           0  ...                    2
# 18523           29116800           0           0  ...                   11
# 245             57888000           0    -2592000  ...                   10
# 19022           15811200           0           0  ...                    7
# 18274            5270400           0           0  ...                    3
# 221             31536000           0    -2678400  ...                   10
# 972             31536000    -2592000   -49939200  ...                    9
# 18884          115689600    -5097600           0  ...                   10
# 395             18403200           0           0  ...                    7
# 640              7776000           0           0  ...                    4
# 756             15811200           0           0  ...                    5
# 443             18489600    52531200           0  ...                    5
# 17730           20995200           0           0  ...                    7
# 179             18576000           0           0  ...                    6
#
#        total_tx_input_count total_tx_input_value  mean_tx_input_value  \
# 454                     189          34032484195  180066053.941798942
# 17477                    23            458066607   19915939.434782609
# 18523                    32           1148851477       35901608.65625
# 245                      44           5873878578  133497240.409090909
# 19022                    36           7842708767  217853021.305555556
# 18274                    30            702842285   23428076.166666667
# 221                      78          18720715045  240009167.243589744
# 972                      77            226834835    2945906.948051948
# 18884                    35            141466355    4041895.857142857
# 395                      45           1056947162   23487714.711111111
# 640                     359          32624642619   90876441.835654596
# 756                     101             70761495     700608.861386139
# 443                    3062         376987387606   123118023.38536904
# 17730                    26           1188853534   45725135.923076923
# 179                     110            409699518    3724541.072727273
#
#        stddev_tx_input_value  total_input_tx mean_monthly_input_value  \
# 454             1.510129e+09              79      180066053.941798942
# 17477           2.541968e+07              15       19915939.434782609
# 18523           5.703211e+07              32           35901608.65625
# 245             1.072190e+08              12      133497240.409090909
# 19022           4.056331e+08              36      217853021.305555556
# 18274           4.002371e+07              16       23428076.166666667
# 221             1.773612e+08              75      240009167.243589744
# 972             3.711472e+06              20        2945906.948051948
# 18884           7.362795e+06              22        4041895.857142857
# 395             3.007607e+07              30       23487714.711111111
# 640             8.461413e+07             330       90876441.835654596
# 756             1.830537e+06              42         700608.861386139
# 443             4.383635e+08            1480       123118023.38536904
# 17730           3.923298e+07              17       45725135.923076923
# 179             1.677856e+06              83        3724541.072727273
#
#        mean_monthly_input_count  mean_output_idle_time  mean_input_idle_time
# 454                         1.0           1.123766e+06          3.244360e+06
# 17477                       1.0           2.560306e+05          4.136118e+05
# 18523                       1.0           1.086613e+06          9.796330e+05
# 245                         1.0           1.408326e+06          5.229244e+06
# 19022                       1.0           4.916560e+05          4.635303e+05
# 18274                       1.0           2.231486e+05          4.018914e+05
# 221                         1.0           5.112707e+05          4.931529e+05
# 972                         1.0           1.042178e+06          1.611577e+06
# 18884                       1.0           3.200231e+06          5.486753e+06
# 395                         1.0           4.358418e+05          6.750330e+05
# 640                         1.0           2.957800e+04          3.002313e+04
# 756                         1.0           1.708274e+05          4.126734e+05
# 443                         1.0           3.269882e+05          1.055010e+05
# 17730                       1.0           8.090101e+05          1.395041e+06
# 179                         1.0           1.686689e+05          2.416737e+05
#
# [15 rows x 28 columns]

# %%
index = inds[: -1]
index
# Out:
# array([13,  9, 17,  0,  2,  8, 10, 18,  4,  1,  5, 22, 21, 11, 19, 14,  7,
#        16, 24, 12,  3, 25,  6, 20, 15], dtype=int64)

# %%
data_top = x_train.columns

# %%
xann = pd.DataFrame(data = x_train_ann[0:, 0:], index = [i for i in range(x_train_ann.shape[0])], columns = [str(i) for i in data_top])
xtann = pd.DataFrame(data = x_test_ann[0:, 0:], index = [i for i in range(x_test_ann.shape[0])], columns = [str(i) for i in data_top])
xrf = x_train
xtrf = x_test
i = 1

# %%
ann_acc = [scores[1] * 100]
rf_acc = [acc * 100]
print("{}- All 26 features taken as input:" .format(i))
print("ANN test accuracy = {}%, RF test accuracy = {}%" .format(ann_acc[0], rf_acc[0]))
for x in reversed(index):
    xann = xann.drop(columns = [data_top[x]])	
    xtann = xtann.drop(columns = [data_top[x]])
    xrf = xrf.drop(columns = [data_top[x]])
    xtrf = xtrf.drop(columns = [data_top[x]])
    
    # Creating model
    ann = Sequential()
    ann.add(Dense(26, activation = 'tanh', kernel_initializer = 'glorot_uniform'))
    ann.add(Dense(11, activation = 'tanh'))
    ann.add(Dropout(0.5))
    ann.add(Dense(6, activation = 'tanh'))
    ann.add(Dense(num_classes, activation = 'softmax'))

    rmsprop = optimizers.RMSprop(learn_rate)
    ann.compile(loss = 'binary_crossentropy', optimizer = rmsprop, metrics = ['binary_accuracy']) # Compiling the model

    # Model fitting
    ann.fit(np.array(xann), y_train_ann, batch_size = batch_size, verbose = 0, epochs = epochs)
    scores_ann = ann.evaluate(xtann, y_test_ann, verbose = 0)

    # Training the model
    rf = RandomForestClassifier(n_estimators = 100, class_weight = 'balanced')
    rf.fit(xrf, y_train)

    # Model predictions
    y_pred = rf.predict(xtrf)
    cnf_matrix = confusion_matrix(y_test, y_pred)
    acc = (cnf_matrix[0][0] + cnf_matrix[1][1]) / (cnf_matrix[0][0] + cnf_matrix[1][1] + cnf_matrix[0][1] + cnf_matrix[1][0])
    i += 1
    print("{}- Dropping {}:" .format(i, data_top[x]))
    print("ANN test accuracy = {}%, RF test accuracy = {}%" .format(scores_ann[1] * 100, acc * 100))
    ann_acc.append(scores_ann[1] * 100)
    rf_acc.append(acc * 100)
# Out:
# 1- All 26 features taken as input:
# ANN test accuracy = 98.62499833106995%, RF test accuracy = 99.02499999999999%
# 2- Dropping mean_monthly_output_count:
# ANN test accuracy = 98.65000247955322%, RF test accuracy = 99.0%
# 3- Dropping stddev_tx_input_value:
# ANN test accuracy = 98.7500011920929%, RF test accuracy = 99.02499999999999%
# 4- Dropping io_max_lag:
# ANN test accuracy = 98.60000014305115%, RF test accuracy = 99.02499999999999%
# 5- Dropping mean_input_idle_time:
# ANN test accuracy = 98.69999885559082%, RF test accuracy = 98.97500000000001%
# 6- Dropping input_month_max:
# ANN test accuracy = 98.62499833106995%, RF test accuracy = 98.97500000000001%
# 7- Dropping stddev_tx_output_value:
# ANN test accuracy = 98.69999885559082%, RF test accuracy = 98.95%
# 8- Dropping mean_output_idle_time:
# ANN test accuracy = 98.62499833106995%, RF test accuracy = 98.925%
# 9- Dropping input_active_months:
# ANN test accuracy = 98.67500066757202%, RF test accuracy = 99.02499999999999%
# 10- Dropping io_min_lag:
# ANN test accuracy = 98.52499961853027%, RF test accuracy = 98.925%
# 11- Dropping mean_monthly_output_value:
# ANN test accuracy = 98.60000014305115%, RF test accuracy = 98.925%
# 12- Dropping mean_tx_input_value:
# ANN test accuracy = 98.50000143051147%, RF test accuracy = 98.97500000000001%
# 13- Dropping mean_tx_output_value:
# ANN test accuracy = 98.60000014305115%, RF test accuracy = 98.95%
# 14- Dropping total_input_tx:
# ANN test accuracy = 98.57500195503235%, RF test accuracy = 98.97500000000001%
# 15- Dropping mean_monthly_input_value:
# ANN test accuracy = 98.54999780654907%, RF test accuracy = 99.0%
# 16- Dropping input_active_time:
# ANN test accuracy = 98.65000247955322%, RF test accuracy = 98.95%
# 17- Dropping output_month_max:
# ANN test accuracy = 98.50000143051147%, RF test accuracy = 99.075%
# 18- Dropping output_active_time:
# ANN test accuracy = 98.72499704360962%, RF test accuracy = 98.9%
# 19- Dropping total_tx_input_value:
# ANN test accuracy = 98.54999780654907%, RF test accuracy = 98.925%
# 20- Dropping total_tx_output_value:
# ANN test accuracy = 98.54999780654907%, RF test accuracy = 98.675%
# 21- Dropping output_active_months:
# ANN test accuracy = 98.4000027179718%, RF test accuracy = 98.55000000000001%
# 22- Dropping input_month_min:
# ANN test accuracy = 98.52499961853027%, RF test accuracy = 98.35000000000001%
# 23- Dropping output_month_min:
# ANN test accuracy = 94.80000138282776%, RF test accuracy = 94.625%
# 24- Dropping total_tx_input_count:
# ANN test accuracy = 94.9999988079071%, RF test accuracy = 94.65%
# 25- Dropping total_tx_output_count:
# ANN test accuracy = 94.82499957084656%, RF test accuracy = 94.65%
# 26- Dropping total_output_tx:
# ANN test accuracy = 49.72499907016754%, RF test accuracy = 49.725%

# %%
# Create plots with pre-defined labels
f = plt.figure(figsize = (10, 10))
ax = f.add_subplot(121)
t = list(np.arange(1., 27., 1))
t.reverse()
ax.plot(t, rf_acc, 'r-', label = 'Random Forest')
ax.plot(t, ann_acc, 'b--', label = 'Artificial Neural Network')

legend = ax.legend(loc = 'lower right', shadow = True, fontsize = 'x-small')

# Put a nicer background color on the legend.
legend.get_frame().set_facecolor('C6')
plt.ylabel('Test Accuracy (%)')
plt.xlabel('Number of features')
plt.title('RF vs ANN (Accuracy Comparison)')
plt.show()

# %%
# Fitting Naive Bayes to the Training set
nb = GaussianNB()
nb.fit(x_train, y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
# Predicting the Test set results
y_pred = nb.predict(x_test)

# %%
# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
class_names = ['not mining pool', 'mining pool']
np.set_printoptions(precision = 3)

# Plot confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes = class_names, normalize = False, title = 'Bitcoin Mining Pool Detector using Naive Bayes - Confusion Matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[1954   35]
#  [ 897 1114]]

# %%
# Calculating Accuracy
acc = (cnf_matrix[0][0] + cnf_matrix[1][1]) / (cnf_matrix[0][0] + cnf_matrix[1][1] + cnf_matrix[0][1] + cnf_matrix[1][0])
print("Test Accuracy (Naive Bayes Classification): {}%" .format(acc * 100))
# Out:
# Test Accuracy (Naive Bayes Classification): 76.7%
