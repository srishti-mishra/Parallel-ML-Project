# %%
from google.cloud import bigquery
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import matplotlib.patheffects as PathEffects
import matplotlib.pylab as pylab
import numpy as np
import pandas as pd
import itertools
from sklearn.metrics import  confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
import time
import seaborn as sns
from keras import utils, optimizers
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.losses import binary_crossentropy
# Out:
# Using TensorFlow backend.

# %%
miner_limit = 20000
non_miner_limit = 20000

# %%
# SQL query adapted from https://gist.github.com/allenday/16cf63fb6b3ed59b78903b2d414fe75b
sql = '''
WITH 
output_ages AS (
  SELECT
    ARRAY_TO_STRING(outputs.addresses,',') AS output_ages_address,
    MIN(block_timestamp_month) AS output_month_min,
    MAX(block_timestamp_month) AS output_month_max
  FROM `bigquery-public-data.crypto_bitcoin.transactions` AS transactions JOIN UNNEST(outputs) AS outputs
  GROUP BY output_ages_address
)
,input_ages AS (
  SELECT
    ARRAY_TO_STRING(inputs.addresses,',') AS input_ages_address,
    MIN(block_timestamp_month) AS input_month_min,
    MAX(block_timestamp_month) AS input_month_max
  FROM `bigquery-public-data.crypto_bitcoin.transactions` AS transactions JOIN UNNEST(inputs) AS inputs
  GROUP BY input_ages_address
)
,output_monthly_stats AS (
  SELECT
    ARRAY_TO_STRING(outputs.addresses,',') AS output_monthly_stats_address, 
    COUNT(DISTINCT block_timestamp_month) AS output_active_months,
    COUNT(outputs) AS total_tx_output_count,
    SUM(value) AS total_tx_output_value,
    AVG(value) AS mean_tx_output_value,
    STDDEV(value) AS stddev_tx_output_value,
    COUNT(DISTINCT(`hash`)) AS total_output_tx,
    SUM(value)/COUNT(block_timestamp_month) AS mean_monthly_output_value,
    COUNT(outputs.addresses)/COUNT(block_timestamp_month) AS mean_monthly_output_count
  FROM `bigquery-public-data.crypto_bitcoin.transactions` AS transactions JOIN UNNEST(outputs) AS outputs
  GROUP BY output_monthly_stats_address
)
,input_monthly_stats AS (
  SELECT
    ARRAY_TO_STRING(inputs.addresses,',') AS input_monthly_stats_address, 
    COUNT(DISTINCT block_timestamp_month) AS input_active_months,
    COUNT(inputs) AS total_tx_input_count,
    SUM(value) AS total_tx_input_value,
    AVG(value) AS mean_tx_input_value,
    STDDEV(value) AS stddev_tx_input_value,
    COUNT(DISTINCT(`hash`)) AS total_input_tx,
    SUM(value)/COUNT(block_timestamp_month) AS mean_monthly_input_value,
    COUNT(inputs.addresses)/COUNT(block_timestamp_month) AS mean_monthly_input_count
  FROM `bigquery-public-data.crypto_bitcoin.transactions` AS transactions JOIN UNNEST(inputs) AS inputs
  GROUP BY input_monthly_stats_address
)
,output_idle_times AS (
  SELECT
    address AS idle_time_address,
    AVG(idle_time) AS mean_output_idle_time,
    STDDEV(idle_time) AS stddev_output_idle_time
  FROM
  (
    SELECT 
      event.address,
      IF(prev_block_time IS NULL, NULL, UNIX_SECONDS(block_time) - UNIX_SECONDS(prev_block_time)) AS idle_time
    FROM (
      SELECT
        ARRAY_TO_STRING(outputs.addresses,',') AS address, 
        block_timestamp AS block_time,
        LAG(block_timestamp) OVER (PARTITION BY ARRAY_TO_STRING(outputs.addresses,',') ORDER BY block_timestamp) AS prev_block_time
      FROM `bigquery-public-data.crypto_bitcoin.transactions` AS transactions JOIN UNNEST(outputs) AS outputs
    ) AS event
    WHERE block_time != prev_block_time
  )
  GROUP BY address
)
,input_idle_times AS (
  SELECT
    address AS idle_time_address,
    AVG(idle_time) AS mean_input_idle_time,
    STDDEV(idle_time) AS stddev_input_idle_time
  FROM
  (
    SELECT 
      event.address,
      IF(prev_block_time IS NULL, NULL, UNIX_SECONDS(block_time) - UNIX_SECONDS(prev_block_time)) AS idle_time
    FROM (
      SELECT
        ARRAY_TO_STRING(inputs.addresses,',') AS address, 
        block_timestamp AS block_time,
        LAG(block_timestamp) OVER (PARTITION BY ARRAY_TO_STRING(inputs.addresses,',') ORDER BY block_timestamp) AS prev_block_time
      FROM `bigquery-public-data.crypto_bitcoin.transactions` AS transactions JOIN UNNEST(inputs) AS inputs
    ) AS event
    WHERE block_time != prev_block_time
  )
  GROUP BY address
)
--,miners AS (
--)

(SELECT
  TRUE AS is_miner,
  output_ages_address AS address,
  UNIX_SECONDS(CAST(output_ages.output_month_min AS TIMESTAMP)) AS output_month_min,
  UNIX_SECONDS(CAST(output_ages.output_month_max AS TIMESTAMP)) AS output_month_max,
  UNIX_SECONDS(CAST(input_ages.input_month_min AS TIMESTAMP)) AS input_month_min,
  UNIX_SECONDS(CAST(input_ages.input_month_max AS TIMESTAMP)) AS input_month_max,
  UNIX_SECONDS(CAST(output_ages.output_month_max AS TIMESTAMP)) - UNIX_SECONDS(CAST(output_ages.output_month_min AS TIMESTAMP)) AS output_active_time,
  UNIX_SECONDS(CAST(input_ages.input_month_max AS TIMESTAMP)) - UNIX_SECONDS(CAST(input_ages.input_month_min AS TIMESTAMP)) AS input_active_time,
  UNIX_SECONDS(CAST(output_ages.output_month_max AS TIMESTAMP)) - UNIX_SECONDS(CAST(input_ages.input_month_max AS TIMESTAMP)) AS io_max_lag,
  UNIX_SECONDS(CAST(output_ages.output_month_min AS TIMESTAMP)) - UNIX_SECONDS(CAST(input_ages.input_month_min AS TIMESTAMP)) AS io_min_lag,
  output_monthly_stats.output_active_months,
  output_monthly_stats.total_tx_output_count,
  output_monthly_stats.total_tx_output_value,
  output_monthly_stats.mean_tx_output_value,
  output_monthly_stats.stddev_tx_output_value,
  output_monthly_stats.total_output_tx,
  output_monthly_stats.mean_monthly_output_value,
  output_monthly_stats.mean_monthly_output_count,
  input_monthly_stats.input_active_months,
  input_monthly_stats.total_tx_input_count,
  input_monthly_stats.total_tx_input_value,
  input_monthly_stats.mean_tx_input_value,
  input_monthly_stats.stddev_tx_input_value,
  input_monthly_stats.total_input_tx,
  input_monthly_stats.mean_monthly_input_value,
  input_monthly_stats.mean_monthly_input_count,
  output_idle_times.mean_output_idle_time,
  output_idle_times.stddev_output_idle_time,
  input_idle_times.mean_input_idle_time,
  input_idle_times.stddev_input_idle_time
FROM
  output_ages, output_monthly_stats, output_idle_times,
  input_ages,  input_monthly_stats, input_idle_times
WHERE TRUE
  AND output_ages.output_ages_address = output_monthly_stats.output_monthly_stats_address
  AND output_ages.output_ages_address = output_idle_times.idle_time_address
  AND output_ages.output_ages_address = input_monthly_stats.input_monthly_stats_address
  AND output_ages.output_ages_address = input_ages.input_ages_address
  AND output_ages.output_ages_address = input_idle_times.idle_time_address
  AND output_ages.output_ages_address IN
(
  SELECT 
    ARRAY_TO_STRING(outputs.addresses,',') AS miner
  FROM 
  `bigquery-public-data.crypto_bitcoin.blocks` AS blocks,
  `bigquery-public-data.crypto_bitcoin.transactions` AS transactions JOIN UNNEST(outputs) AS outputs
  WHERE blocks.hash = transactions.block_hash 
    AND is_coinbase IS TRUE
    AND ( FALSE
      --
      -- miner signatures from https://en.bitcoin.it/wiki/Comparison_of_mining_pools
      --
      OR coinbase_param LIKE '%4d696e656420627920416e74506f6f6c%' --AntPool
      OR coinbase_param LIKE '%2f42434d6f6e737465722f%' --BCMonster
      --BitcoinAffiliateNetwork
      OR coinbase_param LIKE '%4269744d696e746572%' --BitMinter
      --BTC.com
      --BTCC Pool
      --BTCDig
      OR coinbase_param LIKE '%2f7374726174756d2f%' --Btcmp
      --btcZPool.com
      --BW Mining
      OR coinbase_param LIKE '%456c6967697573%' --Eligius
      --F2Pool
      --GHash.IO
      --Give Me COINS
      --Golden Nonce Pool
      OR coinbase_param LIKE '%2f627261766f2d6d696e696e672f%' --Bravo Mining
      OR coinbase_param LIKE '%4b616e6f%' --KanoPool
      --kmdPool.org
      OR coinbase_param LIKE '%2f6d6d706f6f6c%' --Merge Mining Pool
      --MergeMining
      --Multipool
      --P2Pool
      OR coinbase_param LIKE '%2f736c7573682f%' --Slush Pool
      --ZenPool.org
    )
  GROUP BY miner
  HAVING COUNT(1) >= 20 
)
LIMIT {})
UNION ALL
(SELECT
  FALSE AS is_miner,
  output_ages_address AS address,
  UNIX_SECONDS(CAST(output_ages.output_month_min AS TIMESTAMP)) AS output_month_min,
  UNIX_SECONDS(CAST(output_ages.output_month_max AS TIMESTAMP)) AS output_month_max,
  UNIX_SECONDS(CAST(input_ages.input_month_min AS TIMESTAMP)) AS input_month_min,
  UNIX_SECONDS(CAST(input_ages.input_month_max AS TIMESTAMP)) AS input_month_max,
  UNIX_SECONDS(CAST(output_ages.output_month_max AS TIMESTAMP)) - UNIX_SECONDS(CAST(output_ages.output_month_min AS TIMESTAMP)) AS output_active_time,
  UNIX_SECONDS(CAST(input_ages.input_month_max AS TIMESTAMP)) - UNIX_SECONDS(CAST(input_ages.input_month_min AS TIMESTAMP)) AS input_active_time,
  UNIX_SECONDS(CAST(output_ages.output_month_max AS TIMESTAMP)) - UNIX_SECONDS(CAST(input_ages.input_month_max AS TIMESTAMP)) AS io_max_lag,
  UNIX_SECONDS(CAST(output_ages.output_month_min AS TIMESTAMP)) - UNIX_SECONDS(CAST(input_ages.input_month_min AS TIMESTAMP)) AS io_min_lag,
  output_monthly_stats.output_active_months,
  output_monthly_stats.total_tx_output_count,
  output_monthly_stats.total_tx_output_value,
  output_monthly_stats.mean_tx_output_value,
  output_monthly_stats.stddev_tx_output_value,
  output_monthly_stats.total_output_tx,
  output_monthly_stats.mean_monthly_output_value,
  output_monthly_stats.mean_monthly_output_count,
  input_monthly_stats.input_active_months,
  input_monthly_stats.total_tx_input_count,
  input_monthly_stats.total_tx_input_value,
  input_monthly_stats.mean_tx_input_value,
  input_monthly_stats.stddev_tx_input_value,
  input_monthly_stats.total_input_tx,
  input_monthly_stats.mean_monthly_input_value,
  input_monthly_stats.mean_monthly_input_count,
  output_idle_times.mean_output_idle_time,
  output_idle_times.stddev_output_idle_time,
  input_idle_times.mean_input_idle_time,
  input_idle_times.stddev_input_idle_time
FROM
  output_ages, output_monthly_stats, output_idle_times,
  input_ages,  input_monthly_stats, input_idle_times
WHERE TRUE
  AND output_ages.output_ages_address = output_monthly_stats.output_monthly_stats_address
  AND output_ages.output_ages_address = output_idle_times.idle_time_address
  AND output_ages.output_ages_address = input_monthly_stats.input_monthly_stats_address
  AND output_ages.output_ages_address = input_ages.input_ages_address
  AND output_ages.output_ages_address = input_idle_times.idle_time_address
  AND output_ages.output_ages_address NOT IN
(
  SELECT 
    ARRAY_TO_STRING(outputs.addresses,',') AS miner
  FROM 
  `bigquery-public-data.crypto_bitcoin.blocks` AS blocks,
  `bigquery-public-data.crypto_bitcoin.transactions` AS transactions JOIN UNNEST(outputs) AS outputs
  WHERE blocks.hash = transactions.block_hash 
    AND is_coinbase IS TRUE
    AND ( FALSE
      --
      -- miner signatures from https://en.bitcoin.it/wiki/Comparison_of_mining_pools
      --
      OR coinbase_param LIKE '%4d696e656420627920416e74506f6f6c%' --AntPool
      OR coinbase_param LIKE '%2f42434d6f6e737465722f%' --BCMonster
      --BitcoinAffiliateNetwork
      OR coinbase_param LIKE '%4269744d696e746572%' --BitMinter
      --BTC.com
      --BTCC Pool
      --BTCDig
      OR coinbase_param LIKE '%2f7374726174756d2f%' --Btcmp
      --btcZPool.com
      --BW Mining
      OR coinbase_param LIKE '%456c6967697573%' --Eligius
      --F2Pool
      --GHash.IO
      --Give Me COINS
      --Golden Nonce Pool
      OR coinbase_param LIKE '%2f627261766f2d6d696e696e672f%' --Bravo Mining
      OR coinbase_param LIKE '%4b616e6f%' --KanoPool
      --kmdPool.org
      OR coinbase_param LIKE '%2f6d6d706f6f6c%' --Merge Mining Pool
      --MergeMining
      --Multipool
      --P2Pool
      OR coinbase_param LIKE '%2f736c7573682f%' --Slush Pool
      --ZenPool.org
    )
  GROUP BY miner
  HAVING COUNT(1) >= 20 
)
LIMIT {})
'''.format(miner_limit, non_miner_limit)

# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]=r"C:\Users\srish\Documents\NEU\Parallell ML and AI\Untitled Folder\json\My First Project-dd9334d0c0a8.json"
client = bigquery.Client()

# %%
time_start = time.time()
df = client.query(sql).to_dataframe()
print('Time elapsed: {} seconds' .format(time.time() - time_start))
# Out:
# Time elapsed: 231.3158905506134 seconds

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30032 entries, 0 to 30031
# Data columns (total 30 columns):
# is_miner                     30032 non-null bool
# address                      30032 non-null object
# output_month_min             30032 non-null int64
# output_month_max             30032 non-null int64
# input_month_min              30032 non-null int64
# input_month_max              30032 non-null int64
# output_active_time           30032 non-null int64
# input_active_time            30032 non-null int64
# io_max_lag                   30032 non-null int64
# io_min_lag                   30032 non-null int64
# output_active_months         30032 non-null int64
# total_tx_output_count        30032 non-null int64
# total_tx_output_value        30032 non-null object
# mean_tx_output_value         30032 non-null object
# stddev_tx_output_value       30032 non-null float64
# total_output_tx              30032 non-null int64
# mean_monthly_output_value    30032 non-null object
# mean_monthly_output_count    30032 non-null float64
# input_active_months          30032 non-null int64
# total_tx_input_count         30032 non-null int64
# total_tx_input_value         30032 non-null object
# mean_tx_input_value          30032 non-null object
# stddev_tx_input_value        30032 non-null float64
# total_input_tx               30032 non-null int64
# mean_monthly_input_value     30032 non-null object
# mean_monthly_input_count     30032 non-null float64
# mean_output_idle_time        30032 non-null float64
# stddev_output_idle_time      22467 non-null float64
# mean_input_idle_time         30032 non-null float64
# stddev_input_idle_time       21008 non-null float64
# dtypes: bool(1), float64(8), int64(14), object(7)
# memory usage: 6.7+ MB

# %%
# Dropping the columns with null values
df.drop(labels = ['stddev_output_idle_time','stddev_input_idle_time'], axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-f414219df100> in <module>
#       1 # Dropping the columns with null values
# ----> 2 df.drop(labels = ['stddev_output_idle_time','stddev_input_idle_time'], axis = 1, inplace = True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3944                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3945             else:
# -> 3946                 new_axis = axis.drop(labels, errors=errors)
#    3947             result = self.reindex(**{axis_name: new_axis})
#    3948
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5338         if mask.any():
#    5339             if errors != "ignore":
# -> 5340                 raise KeyError("{} not found in axis".format(labels[mask]))
#    5341             indexer = indexer[~mask]
#    5342         return self.delete(indexer)
#
# KeyError: "['stddev_output_idle_time' 'stddev_input_idle_time'] not found in axis"

# %%
df.tail(5)
# Out:
#        is_miner                             address  output_month_min  \
# 30027      True  1JhHa9U3dtn62tJBMwmD79pFzAGzccyDsz        1433116800
# 30028      True  1L8E8YFFxnCjLYnF7EGQDP7A6HU1x69ih3        1393632000
# 30029      True  1PTtmSK8C8RZ94M2PKZfPD9MPd1AjVF2fe        1396310400
# 30030      True  15YyqQ9TBy33v9Bh24U4EeEH73LbTuvNjA        1401580800
# 30031      True  1KkxkjFM5hWWguqg9yYojwquGvYkWDsxop        1385856000
#
#        output_month_max  input_month_min  input_month_max  output_active_time  \
# 30027        1483228800       1433116800       1454284800            50112000
# 30028        1420070400       1396310400       1425168000            26438400
# 30029        1483228800       1401580800       1412121600            86918400
# 30030        1425168000       1433116800       1433116800            23587200
# 30031        1483228800       1385856000       1493596800            97372800
#
#        input_active_time  io_max_lag  io_min_lag  ...  input_active_months  \
# 30027           21168000    28944000           0  ...                    9
# 30028           28857600    -5097600    -2678400  ...                    5
# 30029           10540800    71107200    -5270400  ...                    3
# 30030                  0    -7948800   -31536000  ...                    1
# 30031          107740800   -10368000           0  ...                    4
#
#        total_tx_input_count total_tx_input_value mean_tx_input_value  \
# 30027                    28            113771641   4063272.892857143
# 30028                    29            128224070   4421519.655172414
# 30029                    27            133329135   4938116.111111111
# 30030                    29            154938622   5342711.103448276
# 30031                    29            165711442   5714187.655172414
#
#        stddev_tx_input_value  total_input_tx mean_monthly_input_value  \
# 30027           1.164489e+06              25        4063272.892857143
# 30028           1.015660e+06              12        4421519.655172414
# 30029           1.702039e+06               3        4938116.111111111
# 30030           2.551171e+06               5        5342711.103448276
# 30031           4.120743e+06              29        5714187.655172414
#
#        mean_monthly_input_count  mean_output_idle_time  mean_input_idle_time
# 30027                       1.0           1.761098e+06          8.305231e+05
# 30028                       1.0           8.880577e+05          2.638014e+06
# 30029                       1.0           3.086152e+06          5.804395e+06
# 30030                       1.0           8.815122e+05          5.695000e+02
# 30031                       1.0           3.452747e+06          3.894107e+06
#
# [5 rows x 28 columns]

# %%
df.head(5)
# Out:
#    is_miner                             address  output_month_min  \
# 0     False  1AdvDutFsj1DNwyPhsmj9EQAdw425BSN5y        1456790400
# 1     False   1KeAMGzhtS6pSYXKqLrK5uUAn3BiibYYK        1388534400
# 2     False  1EvStKVaqyAYNPpaUnyX25nB7wtb7Uk2BE        1488326400
# 3     False  1ECXtFsvyYofEWseyodY14BVYXxXpD1Vit        1398902400
# 4     False  13uKZnnBwuFag7RpHPz9FeSs2rr3wpYMqB        1548979200
#
#    output_month_max  input_month_min  input_month_max  output_active_time  \
# 0        1462060800       1456790400       1462060800             5270400
# 1        1401580800       1388534400       1409529600            13046400
# 2        1522540800       1488326400       1530403200            34214400
# 3        1406851200       1398902400       1406851200             7948800
# 4        1575158400       1548979200       1575158400            26179200
#
#    input_active_time  io_max_lag  io_min_lag  ...  input_active_months  \
# 0            5270400           0           0  ...                    3
# 1           20995200    -7948800           0  ...                    6
# 2           42076800    -7862400           0  ...                   10
# 3            7948800           0           0  ...                    4
# 4           26179200           0           0  ...                    9
#
#    total_tx_input_count total_tx_input_value mean_tx_input_value  \
# 0                    90             37829724    420330.266666667
# 1                    17            634548662  37326391.882352941
# 2                    22            266050000  12093181.818181818
# 3                    16            286138200          17883637.5
# 4                    42                22932                 546
#
#    stddev_tx_input_value  total_input_tx mean_monthly_input_value  \
# 0           3.835928e+05              76         420330.266666667
# 1           4.442080e+07              17       37326391.882352941
# 2           1.286505e+07              18       12093181.818181818
# 3           1.371118e+07              16               17883637.5
# 4           0.000000e+00              42                      546
#
#    mean_monthly_input_count  mean_output_idle_time  mean_input_idle_time
# 0                       1.0           5.773151e+04          7.229046e+04
# 1                       1.0           7.612386e+05          1.273466e+06
# 2                       1.0           1.688905e+06          2.535400e+06
# 3                       1.0           5.276024e+05          5.273205e+05
# 4                       1.0           6.098085e+05          6.373037e+05
#
# [5 rows x 28 columns]

# %%
df.shape
# Out:
# (30032, 28)

# %%
# Dropping the non-numeric features
features = df.drop(labels = ['is_miner', 'address'], axis = 1)
target = df['is_miner'].values
indices = range(len(features))

# %%
sns.set_style('darkgrid')
sns.set_palette('muted')
sns.set_context("notebook", font_scale = 1.5, rc = {"lines.linewidth": 2.5})

# %%
def bitcoin_scatter(x, colors):
    # choose a color palette with seaborn.
    num_classes = len(np.unique(colors))
    palette = np.array(sns.color_palette("hls", num_classes))

    # create a scatter plot.
    f = plt.figure(figsize = (8, 8))
    ax = plt.subplot(aspect = 'equal')
    sc = ax.scatter(x[:,0], x[:,1], lw = 0, s = 40, c=palette[colors.astype(np.int)])
    plt.xlim(-25, 25)
    plt.ylim(-25, 25)
    ax.axis('off')
    ax.axis('tight')
    plt.title('t-SNE to visualize features')

    # add the labels for each digit corresponding to the label
    txts = []

    for i in range(num_classes):

        # Position of each label at median of data points.

        xtext, ytext = np.median(x[colors == i, :], axis = 0)
        txt = ax.text(xtext, ytext, str(i), fontsize = 24)
        txt.set_path_effects([
            PathEffects.Stroke(linewidth = 5, foreground = "w"),
            PathEffects.Normal()])
        txts.append(txt)

    return f, ax, sc, txts

# %%
time_start = time.time()
RS = 123
bitcoin_tsne = TSNE(random_state = RS).fit_transform(features)
print('Time elapsed: {} seconds' .format(time.time() - time_start))
# Out:
# Time elapsed: 374.1112582683563 seconds

# %%
bitcoin_scatter(bitcoin_tsne, target)
# Out:
# (<Figure size 576x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x17d1cb7d708>,
#  <matplotlib.collections.PathCollection at 0x17d1d58e888>,
#  [Text(-15.588844, 1.2880156, '0'), Text(27.48837, -29.760773, '1')])

# %%
plt.savefig('tSNE2.jpg')

# %%
# Splitting the training and testing dataset
x_train, x_test, y_train, y_test, indices_train, indices_test = train_test_split(features, target, indices,  test_size = 0.2)

# %%
x_train.head()
# Out:
#        output_month_min  output_month_max  input_month_min  input_month_max  \
# 3308         1396310400        1493596800       1398902400       1493596800
# 14716        1501545600        1501545600       1509494400       1509494400
# 11899        1338508800        1338508800       1338508800       1338508800
# 8074         1312156800        1372636800       1314835200       1372636800
# 370          1488326400        1488326400       1488326400       1488326400
#
#        output_active_time  input_active_time  io_max_lag  io_min_lag  \
# 3308             97286400           94694400           0    -2592000
# 14716                   0                  0    -7948800    -7948800
# 11899                   0                  0           0           0
# 8074             60480000           57801600           0    -2678400
# 370                     0                  0           0           0
#
#        output_active_months  total_tx_output_count  ... input_active_months  \
# 3308                     29                     98  ...                  13
# 14716                     1                      2  ...                   1
# 11899                     1                      2  ...                   1
# 8074                     20                     95  ...                  12
# 370                       1                     23  ...                   1
#
#       total_tx_input_count  total_tx_input_value  mean_tx_input_value  \
# 3308                    98             483816581    4936903.887755102
# 14716                    2             500710645          250355322.5
# 11899                    2              32318718             16159359
# 8074                    94            5863849260   62381375.106382979
# 370                     23               4168798     181252.086956522
#
#       stddev_tx_input_value  total_input_tx  mean_monthly_input_value  \
# 3308           1.580142e+06              14         4936903.887755102
# 14716          3.529423e+08               2               250355322.5
# 11899          5.850771e+06               2                  16159359
# 8074           6.468484e+07              41        62381375.106382979
# 370            1.929751e+05              23          181252.086956522
#
#        mean_monthly_input_count mean_output_idle_time mean_input_idle_time
# 3308                        1.0          1.006156e+06         7.278906e+06
# 14716                       1.0          1.199600e+04         1.090000e+03
# 11899                       1.0          3.490000e+03         2.370900e+04
# 8074                        1.0          6.493174e+05         1.503604e+06
# 370                         1.0          8.283009e+04         8.280332e+04
#
# [5 rows x 26 columns]

# %%
x_train.shape
# Out:
# (24025, 26)

# %%
y_train
# Out:
# array([ True, False, False, ...,  True, False,  True])

# %%
# Feature Scaling
sc_x = StandardScaler()
x_train_ann = sc_x.fit_transform(x_train)
x_test_ann = sc_x.transform(x_test)

# %%
num_classes = 2

# Hyperparameters
learn_rate = 0.001
batch_size = 500
epochs = 270

# %%
# Encoding the Dependent Variable
labelencoder_y = LabelEncoder()
y_train_ann = labelencoder_y.fit_transform(y_train)

# Converting to binary class matrix
y_train_ann = utils.to_categorical(y_train_ann, num_classes)

# %%
y_train_ann.shape
# Out:
# (24025, 2)

# %%
# Encoding the Dependent Variable
labelencoder_y = LabelEncoder()
y_test_ann = labelencoder_y.fit_transform(y_test)

# Converting to binary class matrix
y_test_ann = utils.to_categorical(y_test_ann, num_classes)

# %%
y_test_ann.shape
# Out:
# (6007, 2)

# %%
seed = 1
np.random.seed(seed)

# Creating model
ann = Sequential()
ann.add(Dense(26, activation = 'tanh', kernel_initializer = 'glorot_uniform'))
ann.add(Dense(11, activation = 'tanh'))
ann.add(Dropout(0.5))
ann.add(Dense(6, activation = 'tanh'))
ann.add(Dense(num_classes, activation = 'softmax'))

# %%
rmsprop = optimizers.RMSprop(learn_rate)
ann.compile(loss = 'binary_crossentropy', optimizer = rmsprop, metrics = ['binary_accuracy']) # Compiling the model

# %%
# Model fitting
ann.fit(np.array(x_train_ann), y_train_ann, batch_size = batch_size, epochs = epochs, validation_data = (x_test_ann, y_test_ann))
# Out:
# Train on 24025 samples, validate on 6007 samples
# Epoch 1/270
# 24025/24025 [==============================] - 1s 38us/step - loss: 0.3471 - binary_accuracy: 0.8796 - val_loss: 0.1909 - val_binary_accuracy: 0.9441
# Epoch 2/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.1981 - binary_accuracy: 0.9360 - val_loss: 0.1357 - val_binary_accuracy: 0.9522
# Epoch 3/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.1497 - binary_accuracy: 0.9522 - val_loss: 0.1088 - val_binary_accuracy: 0.9644
# Epoch 4/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.1247 - binary_accuracy: 0.9591 - val_loss: 0.0923 - val_binary_accuracy: 0.9697
# Epoch 5/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.1074 - binary_accuracy: 0.9666 - val_loss: 0.0798 - val_binary_accuracy: 0.9765
# Epoch 6/270
# 24025/24025 [==============================] - 0s 9us/step - loss: 0.0963 - binary_accuracy: 0.9697 - val_loss: 0.0708 - val_binary_accuracy: 0.9780
# Epoch 7/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0882 - binary_accuracy: 0.9723 - val_loss: 0.0656 - val_binary_accuracy: 0.9822
# Epoch 8/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0818 - binary_accuracy: 0.9750 - val_loss: 0.0654 - val_binary_accuracy: 0.9830
# Epoch 9/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0806 - binary_accuracy: 0.9759 - val_loss: 0.0609 - val_binary_accuracy: 0.9822
# Epoch 10/270
# 24025/24025 [==============================] - 0s 11us/step - loss: 0.0776 - binary_accuracy: 0.9761 - val_loss: 0.0595 - val_binary_accuracy: 0.9824
# Epoch 11/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0774 - binary_accuracy: 0.9761 - val_loss: 0.0587 - val_binary_accuracy: 0.9829
# Epoch 12/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0743 - binary_accuracy: 0.9779 - val_loss: 0.0615 - val_binary_accuracy: 0.9799
# Epoch 13/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0729 - binary_accuracy: 0.9780 - val_loss: 0.0593 - val_binary_accuracy: 0.9845
# Epoch 14/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0726 - binary_accuracy: 0.9783 - val_loss: 0.0574 - val_binary_accuracy: 0.9844
# Epoch 15/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0715 - binary_accuracy: 0.9786 - val_loss: 0.0548 - val_binary_accuracy: 0.9842
# Epoch 16/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0699 - binary_accuracy: 0.9789 - val_loss: 0.0552 - val_binary_accuracy: 0.9827
# Epoch 17/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0691 - binary_accuracy: 0.9794 - val_loss: 0.0562 - val_binary_accuracy: 0.9824
# Epoch 18/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0687 - binary_accuracy: 0.9793 - val_loss: 0.0588 - val_binary_accuracy: 0.9807
# Epoch 19/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0687 - binary_accuracy: 0.9792 - val_loss: 0.0641 - val_binary_accuracy: 0.9842
# Epoch 20/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0667 - binary_accuracy: 0.9804 - val_loss: 0.0598 - val_binary_accuracy: 0.9802
# Epoch 21/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0647 - binary_accuracy: 0.9801 - val_loss: 0.0520 - val_binary_accuracy: 0.9847
# Epoch 22/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0650 - binary_accuracy: 0.9804 - val_loss: 0.0540 - val_binary_accuracy: 0.9844
# Epoch 23/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0640 - binary_accuracy: 0.9816 - val_loss: 0.0551 - val_binary_accuracy: 0.9815
# Epoch 24/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0634 - binary_accuracy: 0.9814 - val_loss: 0.0544 - val_binary_accuracy: 0.9854
# Epoch 25/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0631 - binary_accuracy: 0.9811 - val_loss: 0.0537 - val_binary_accuracy: 0.9849
# Epoch 26/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0636 - binary_accuracy: 0.9806 - val_loss: 0.0509 - val_binary_accuracy: 0.9837
# Epoch 27/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0627 - binary_accuracy: 0.9814 - val_loss: 0.0544 - val_binary_accuracy: 0.9845
# Epoch 28/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0627 - binary_accuracy: 0.9815 - val_loss: 0.0495 - val_binary_accuracy: 0.9850
# Epoch 29/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0611 - binary_accuracy: 0.9818 - val_loss: 0.0687 - val_binary_accuracy: 0.9800
# Epoch 30/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0622 - binary_accuracy: 0.9823 - val_loss: 0.0504 - val_binary_accuracy: 0.9840
# Epoch 31/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0617 - binary_accuracy: 0.9820 - val_loss: 0.0494 - val_binary_accuracy: 0.9855
# Epoch 32/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0606 - binary_accuracy: 0.9818 - val_loss: 0.0487 - val_binary_accuracy: 0.9847
# Epoch 33/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0603 - binary_accuracy: 0.9816 - val_loss: 0.0485 - val_binary_accuracy: 0.9860
# Epoch 34/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0591 - binary_accuracy: 0.9826 - val_loss: 0.0489 - val_binary_accuracy: 0.9850
# Epoch 35/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0605 - binary_accuracy: 0.9824 - val_loss: 0.0488 - val_binary_accuracy: 0.9852
# Epoch 36/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0582 - binary_accuracy: 0.9828 - val_loss: 0.0479 - val_binary_accuracy: 0.9862
# Epoch 37/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0585 - binary_accuracy: 0.9830 - val_loss: 0.0482 - val_binary_accuracy: 0.9852
# Epoch 38/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0568 - binary_accuracy: 0.9830 - val_loss: 0.0477 - val_binary_accuracy: 0.9862
# Epoch 39/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0572 - binary_accuracy: 0.9834 - val_loss: 0.0523 - val_binary_accuracy: 0.9854
# Epoch 40/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0571 - binary_accuracy: 0.9828 - val_loss: 0.0470 - val_binary_accuracy: 0.9863
# Epoch 41/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0584 - binary_accuracy: 0.9826 - val_loss: 0.0463 - val_binary_accuracy: 0.9873
# Epoch 42/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0570 - binary_accuracy: 0.9826 - val_loss: 0.0467 - val_binary_accuracy: 0.9863
# Epoch 43/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0567 - binary_accuracy: 0.9833 - val_loss: 0.0471 - val_binary_accuracy: 0.9860
# Epoch 44/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0567 - binary_accuracy: 0.9833 - val_loss: 0.0470 - val_binary_accuracy: 0.9868
# Epoch 45/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0583 - binary_accuracy: 0.9822 - val_loss: 0.0470 - val_binary_accuracy: 0.9865
# Epoch 46/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0558 - binary_accuracy: 0.9838 - val_loss: 0.0456 - val_binary_accuracy: 0.9870
# Epoch 47/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0565 - binary_accuracy: 0.9829 - val_loss: 0.0456 - val_binary_accuracy: 0.9868
# Epoch 48/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0559 - binary_accuracy: 0.9828 - val_loss: 0.0471 - val_binary_accuracy: 0.9865
# Epoch 49/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0557 - binary_accuracy: 0.9834 - val_loss: 0.0463 - val_binary_accuracy: 0.9862
# Epoch 50/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0554 - binary_accuracy: 0.9839 - val_loss: 0.0506 - val_binary_accuracy: 0.9849
# Epoch 51/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0555 - binary_accuracy: 0.9836 - val_loss: 0.0487 - val_binary_accuracy: 0.9849
# Epoch 52/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0562 - binary_accuracy: 0.9834 - val_loss: 0.0458 - val_binary_accuracy: 0.9870
# Epoch 53/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0554 - binary_accuracy: 0.9836 - val_loss: 0.0451 - val_binary_accuracy: 0.9872
# Epoch 54/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0561 - binary_accuracy: 0.9831 - val_loss: 0.0478 - val_binary_accuracy: 0.9849
# Epoch 55/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0548 - binary_accuracy: 0.9837 - val_loss: 0.0465 - val_binary_accuracy: 0.9863
# Epoch 56/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0534 - binary_accuracy: 0.9840 - val_loss: 0.0508 - val_binary_accuracy: 0.9845
# Epoch 57/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0540 - binary_accuracy: 0.9842 - val_loss: 0.0460 - val_binary_accuracy: 0.9867
# Epoch 58/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0540 - binary_accuracy: 0.9827 - val_loss: 0.0459 - val_binary_accuracy: 0.9865
# Epoch 59/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0540 - binary_accuracy: 0.9840 - val_loss: 0.0464 - val_binary_accuracy: 0.9858
# Epoch 60/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0538 - binary_accuracy: 0.9840 - val_loss: 0.0452 - val_binary_accuracy: 0.9863
# Epoch 61/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0536 - binary_accuracy: 0.9841 - val_loss: 0.0451 - val_binary_accuracy: 0.9870
# Epoch 62/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0544 - binary_accuracy: 0.9842 - val_loss: 0.0458 - val_binary_accuracy: 0.9862
# Epoch 63/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0543 - binary_accuracy: 0.9834 - val_loss: 0.0441 - val_binary_accuracy: 0.9873
# Epoch 64/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0538 - binary_accuracy: 0.9838 - val_loss: 0.0458 - val_binary_accuracy: 0.9868
# Epoch 65/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0524 - binary_accuracy: 0.9844 - val_loss: 0.0447 - val_binary_accuracy: 0.9868
# Epoch 66/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0525 - binary_accuracy: 0.9845 - val_loss: 0.0510 - val_binary_accuracy: 0.9839
# Epoch 67/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0533 - binary_accuracy: 0.9836 - val_loss: 0.0460 - val_binary_accuracy: 0.9868
# Epoch 68/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0532 - binary_accuracy: 0.9843 - val_loss: 0.0448 - val_binary_accuracy: 0.9873
# Epoch 69/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0521 - binary_accuracy: 0.9846 - val_loss: 0.0498 - val_binary_accuracy: 0.9847
# Epoch 70/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0542 - binary_accuracy: 0.9840 - val_loss: 0.0443 - val_binary_accuracy: 0.9868
# Epoch 71/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0526 - binary_accuracy: 0.9844 - val_loss: 0.0445 - val_binary_accuracy: 0.9872
# Epoch 72/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0519 - binary_accuracy: 0.9841 - val_loss: 0.0714 - val_binary_accuracy: 0.9737
# Epoch 73/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0532 - binary_accuracy: 0.9839 - val_loss: 0.0442 - val_binary_accuracy: 0.9875
# Epoch 74/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0521 - binary_accuracy: 0.9850 - val_loss: 0.0456 - val_binary_accuracy: 0.9868
# Epoch 75/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0530 - binary_accuracy: 0.9843 - val_loss: 0.0441 - val_binary_accuracy: 0.9868
# Epoch 76/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0513 - binary_accuracy: 0.9849 - val_loss: 0.0450 - val_binary_accuracy: 0.9872
# Epoch 77/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0517 - binary_accuracy: 0.9846 - val_loss: 0.0436 - val_binary_accuracy: 0.9868
# Epoch 78/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0504 - binary_accuracy: 0.9851 - val_loss: 0.0436 - val_binary_accuracy: 0.9868
# Epoch 79/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0511 - binary_accuracy: 0.9848 - val_loss: 0.0566 - val_binary_accuracy: 0.9824
# Epoch 80/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0512 - binary_accuracy: 0.9848 - val_loss: 0.0441 - val_binary_accuracy: 0.9875
# Epoch 81/270
# 24025/24025 [==============================] - 0s 9us/step - loss: 0.0501 - binary_accuracy: 0.9854 - val_loss: 0.0464 - val_binary_accuracy: 0.9858
# Epoch 82/270
# 24025/24025 [==============================] - 0s 10us/step - loss: 0.0511 - binary_accuracy: 0.9853 - val_loss: 0.0474 - val_binary_accuracy: 0.9862
# Epoch 83/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0521 - binary_accuracy: 0.9847 - val_loss: 0.0444 - val_binary_accuracy: 0.9868
# Epoch 84/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0509 - binary_accuracy: 0.9848 - val_loss: 0.0575 - val_binary_accuracy: 0.9815
# Epoch 85/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0514 - binary_accuracy: 0.9849 - val_loss: 0.0459 - val_binary_accuracy: 0.9865
# Epoch 86/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0520 - binary_accuracy: 0.9844 - val_loss: 0.0439 - val_binary_accuracy: 0.9870
# Epoch 87/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0504 - binary_accuracy: 0.9849 - val_loss: 0.0445 - val_binary_accuracy: 0.9870
# Epoch 88/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0514 - binary_accuracy: 0.9851 - val_loss: 0.0434 - val_binary_accuracy: 0.9872
# Epoch 89/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0512 - binary_accuracy: 0.9850 - val_loss: 0.0446 - val_binary_accuracy: 0.9865
# Epoch 90/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0513 - binary_accuracy: 0.9849 - val_loss: 0.0440 - val_binary_accuracy: 0.9870
# Epoch 91/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0496 - binary_accuracy: 0.9848 - val_loss: 0.0505 - val_binary_accuracy: 0.9845
# Epoch 92/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0500 - binary_accuracy: 0.9849 - val_loss: 0.0438 - val_binary_accuracy: 0.9867
# Epoch 93/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0504 - binary_accuracy: 0.9851 - val_loss: 0.0451 - val_binary_accuracy: 0.9872
# Epoch 94/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0517 - binary_accuracy: 0.9841 - val_loss: 0.0434 - val_binary_accuracy: 0.9870
# Epoch 95/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0491 - binary_accuracy: 0.9850 - val_loss: 0.0436 - val_binary_accuracy: 0.9875
# Epoch 96/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0500 - binary_accuracy: 0.9856 - val_loss: 0.0442 - val_binary_accuracy: 0.9868
# Epoch 97/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0511 - binary_accuracy: 0.9848 - val_loss: 0.0428 - val_binary_accuracy: 0.9872
# Epoch 98/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0506 - binary_accuracy: 0.9846 - val_loss: 0.0438 - val_binary_accuracy: 0.9867
# Epoch 99/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0498 - binary_accuracy: 0.9846 - val_loss: 0.0438 - val_binary_accuracy: 0.9870
# Epoch 100/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0492 - binary_accuracy: 0.9855 - val_loss: 0.0514 - val_binary_accuracy: 0.9852
# Epoch 101/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0496 - binary_accuracy: 0.9857 - val_loss: 0.0439 - val_binary_accuracy: 0.9870
# Epoch 102/270
# 24025/24025 [==============================] - 0s 10us/step - loss: 0.0495 - binary_accuracy: 0.9854 - val_loss: 0.0444 - val_binary_accuracy: 0.9867
# Epoch 103/270
# 24025/24025 [==============================] - 0s 11us/step - loss: 0.0501 - binary_accuracy: 0.9847 - val_loss: 0.0440 - val_binary_accuracy: 0.9872
# Epoch 104/270
# 24025/24025 [==============================] - 0s 12us/step - loss: 0.0496 - binary_accuracy: 0.9850 - val_loss: 0.0475 - val_binary_accuracy: 0.9857
# Epoch 105/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0499 - binary_accuracy: 0.9851 - val_loss: 0.0430 - val_binary_accuracy: 0.9868
# Epoch 106/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0503 - binary_accuracy: 0.9851 - val_loss: 0.0435 - val_binary_accuracy: 0.9870
# Epoch 107/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0489 - binary_accuracy: 0.9850 - val_loss: 0.0443 - val_binary_accuracy: 0.9865
# Epoch 108/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0486 - binary_accuracy: 0.9856 - val_loss: 0.0438 - val_binary_accuracy: 0.9868
# Epoch 109/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0494 - binary_accuracy: 0.9855 - val_loss: 0.0495 - val_binary_accuracy: 0.9852
# Epoch 110/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0484 - binary_accuracy: 0.9856 - val_loss: 0.0514 - val_binary_accuracy: 0.9844
# Epoch 111/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0503 - binary_accuracy: 0.9852 - val_loss: 0.0456 - val_binary_accuracy: 0.9868
# Epoch 112/270
# 24025/24025 [==============================] - 0s 10us/step - loss: 0.0481 - binary_accuracy: 0.9858 - val_loss: 0.0435 - val_binary_accuracy: 0.9872
# Epoch 113/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0486 - binary_accuracy: 0.9857 - val_loss: 0.0447 - val_binary_accuracy: 0.9868
# Epoch 114/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0490 - binary_accuracy: 0.9855 - val_loss: 0.0432 - val_binary_accuracy: 0.9872
# Epoch 115/270
# 24025/24025 [==============================] - 0s 10us/step - loss: 0.0493 - binary_accuracy: 0.9852 - val_loss: 0.0461 - val_binary_accuracy: 0.9860
# Epoch 116/270
# 24025/24025 [==============================] - 0s 9us/step - loss: 0.0489 - binary_accuracy: 0.9852 - val_loss: 0.0507 - val_binary_accuracy: 0.9847
# Epoch 117/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0493 - binary_accuracy: 0.9850 - val_loss: 0.0482 - val_binary_accuracy: 0.9855
# Epoch 118/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0486 - binary_accuracy: 0.9848 - val_loss: 0.0465 - val_binary_accuracy: 0.9868
# Epoch 119/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0494 - binary_accuracy: 0.9854 - val_loss: 0.0457 - val_binary_accuracy: 0.9868
# Epoch 120/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0494 - binary_accuracy: 0.9858 - val_loss: 0.0429 - val_binary_accuracy: 0.9872
# Epoch 121/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0486 - binary_accuracy: 0.9853 - val_loss: 0.0436 - val_binary_accuracy: 0.9873
# Epoch 122/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0499 - binary_accuracy: 0.9852 - val_loss: 0.0537 - val_binary_accuracy: 0.9844
# Epoch 123/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0488 - binary_accuracy: 0.9856 - val_loss: 0.0527 - val_binary_accuracy: 0.9835
# Epoch 124/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0490 - binary_accuracy: 0.9848 - val_loss: 0.0437 - val_binary_accuracy: 0.9868
# Epoch 125/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0493 - binary_accuracy: 0.9856 - val_loss: 0.0471 - val_binary_accuracy: 0.9863
# Epoch 126/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0494 - binary_accuracy: 0.9856 - val_loss: 0.0439 - val_binary_accuracy: 0.9875
# Epoch 127/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0479 - binary_accuracy: 0.9853 - val_loss: 0.0439 - val_binary_accuracy: 0.9870
# Epoch 128/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0489 - binary_accuracy: 0.9852 - val_loss: 0.0439 - val_binary_accuracy: 0.9868
# Epoch 129/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0488 - binary_accuracy: 0.9855 - val_loss: 0.0436 - val_binary_accuracy: 0.9870
# Epoch 130/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0472 - binary_accuracy: 0.9858 - val_loss: 0.0430 - val_binary_accuracy: 0.9875
# Epoch 131/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0489 - binary_accuracy: 0.9851 - val_loss: 0.0432 - val_binary_accuracy: 0.9872
# Epoch 132/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0485 - binary_accuracy: 0.9852 - val_loss: 0.0488 - val_binary_accuracy: 0.9862
# Epoch 133/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0482 - binary_accuracy: 0.9853 - val_loss: 0.0442 - val_binary_accuracy: 0.9875
# Epoch 134/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0477 - binary_accuracy: 0.9854 - val_loss: 0.0435 - val_binary_accuracy: 0.9870
# Epoch 135/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0478 - binary_accuracy: 0.9851 - val_loss: 0.0432 - val_binary_accuracy: 0.9868
# Epoch 136/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0477 - binary_accuracy: 0.9853 - val_loss: 0.0444 - val_binary_accuracy: 0.9865
# Epoch 137/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0484 - binary_accuracy: 0.9854 - val_loss: 0.0450 - val_binary_accuracy: 0.9877
# Epoch 138/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0473 - binary_accuracy: 0.9860 - val_loss: 0.0629 - val_binary_accuracy: 0.9785
# Epoch 139/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0478 - binary_accuracy: 0.9857 - val_loss: 0.0445 - val_binary_accuracy: 0.9870
# Epoch 140/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0482 - binary_accuracy: 0.9855 - val_loss: 0.0439 - val_binary_accuracy: 0.9873
# Epoch 141/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0477 - binary_accuracy: 0.9861 - val_loss: 0.0433 - val_binary_accuracy: 0.9868
# Epoch 142/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0475 - binary_accuracy: 0.9857 - val_loss: 0.0531 - val_binary_accuracy: 0.9837
# Epoch 143/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0481 - binary_accuracy: 0.9859 - val_loss: 0.0437 - val_binary_accuracy: 0.9870
# Epoch 144/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0478 - binary_accuracy: 0.9860 - val_loss: 0.0431 - val_binary_accuracy: 0.9875
# Epoch 145/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0478 - binary_accuracy: 0.9854 - val_loss: 0.0437 - val_binary_accuracy: 0.9880
# Epoch 146/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0474 - binary_accuracy: 0.9852 - val_loss: 0.0435 - val_binary_accuracy: 0.9877
# Epoch 147/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0473 - binary_accuracy: 0.9856 - val_loss: 0.0722 - val_binary_accuracy: 0.9740
# Epoch 148/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0483 - binary_accuracy: 0.9858 - val_loss: 0.0443 - val_binary_accuracy: 0.9873
# Epoch 149/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0487 - binary_accuracy: 0.9855 - val_loss: 0.0444 - val_binary_accuracy: 0.9870
# Epoch 150/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0485 - binary_accuracy: 0.9853 - val_loss: 0.0436 - val_binary_accuracy: 0.9872
# Epoch 151/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0479 - binary_accuracy: 0.9853 - val_loss: 0.0434 - val_binary_accuracy: 0.9873
# Epoch 152/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0475 - binary_accuracy: 0.9852 - val_loss: 0.0438 - val_binary_accuracy: 0.9868
# Epoch 153/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0477 - binary_accuracy: 0.9860 - val_loss: 0.0437 - val_binary_accuracy: 0.9867
# Epoch 154/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0473 - binary_accuracy: 0.9863 - val_loss: 0.0446 - val_binary_accuracy: 0.9863
# Epoch 155/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0476 - binary_accuracy: 0.9856 - val_loss: 0.0434 - val_binary_accuracy: 0.9872
# Epoch 156/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0472 - binary_accuracy: 0.9862 - val_loss: 0.0438 - val_binary_accuracy: 0.9872
# Epoch 157/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0471 - binary_accuracy: 0.9861 - val_loss: 0.0436 - val_binary_accuracy: 0.9877
# Epoch 158/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0472 - binary_accuracy: 0.9856 - val_loss: 0.0434 - val_binary_accuracy: 0.9875
# Epoch 159/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0485 - binary_accuracy: 0.9858 - val_loss: 0.0439 - val_binary_accuracy: 0.9872
# Epoch 160/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0475 - binary_accuracy: 0.9858 - val_loss: 0.0433 - val_binary_accuracy: 0.9873
# Epoch 161/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0475 - binary_accuracy: 0.9861 - val_loss: 0.0448 - val_binary_accuracy: 0.9868
# Epoch 162/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0474 - binary_accuracy: 0.9857 - val_loss: 0.0439 - val_binary_accuracy: 0.9870
# Epoch 163/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0474 - binary_accuracy: 0.9851 - val_loss: 0.0436 - val_binary_accuracy: 0.9867
# Epoch 164/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0473 - binary_accuracy: 0.9857 - val_loss: 0.0441 - val_binary_accuracy: 0.9870
# Epoch 165/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0470 - binary_accuracy: 0.9857 - val_loss: 0.0447 - val_binary_accuracy: 0.9872
# Epoch 166/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0459 - binary_accuracy: 0.9863 - val_loss: 0.0443 - val_binary_accuracy: 0.9870
# Epoch 167/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0469 - binary_accuracy: 0.9856 - val_loss: 0.0432 - val_binary_accuracy: 0.9873
# Epoch 168/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0471 - binary_accuracy: 0.9863 - val_loss: 0.0449 - val_binary_accuracy: 0.9870
# Epoch 169/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0468 - binary_accuracy: 0.9862 - val_loss: 0.0438 - val_binary_accuracy: 0.9872
# Epoch 170/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0470 - binary_accuracy: 0.9853 - val_loss: 0.0446 - val_binary_accuracy: 0.9867
# Epoch 171/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0473 - binary_accuracy: 0.9858 - val_loss: 0.0442 - val_binary_accuracy: 0.9872
# Epoch 172/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0478 - binary_accuracy: 0.9861 - val_loss: 0.0435 - val_binary_accuracy: 0.9868
# Epoch 173/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0468 - binary_accuracy: 0.9855 - val_loss: 0.0446 - val_binary_accuracy: 0.9868
# Epoch 174/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0480 - binary_accuracy: 0.9855 - val_loss: 0.0433 - val_binary_accuracy: 0.9880
# Epoch 175/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0463 - binary_accuracy: 0.9863 - val_loss: 0.0434 - val_binary_accuracy: 0.9873
# Epoch 176/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0467 - binary_accuracy: 0.9860 - val_loss: 0.0433 - val_binary_accuracy: 0.9868
# Epoch 177/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0465 - binary_accuracy: 0.9862 - val_loss: 0.0526 - val_binary_accuracy: 0.9839
# Epoch 178/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0466 - binary_accuracy: 0.9858 - val_loss: 0.0443 - val_binary_accuracy: 0.9870
# Epoch 179/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0453 - binary_accuracy: 0.9866 - val_loss: 0.0475 - val_binary_accuracy: 0.9865
# Epoch 180/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0468 - binary_accuracy: 0.9855 - val_loss: 0.0440 - val_binary_accuracy: 0.9873
# Epoch 181/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0478 - binary_accuracy: 0.9856 - val_loss: 0.0434 - val_binary_accuracy: 0.9867
# Epoch 182/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0449 - binary_accuracy: 0.9867 - val_loss: 0.0433 - val_binary_accuracy: 0.9872
# Epoch 183/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0465 - binary_accuracy: 0.9860 - val_loss: 0.0438 - val_binary_accuracy: 0.9870
# Epoch 184/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0461 - binary_accuracy: 0.9856 - val_loss: 0.0499 - val_binary_accuracy: 0.9849
# Epoch 185/270
# 24025/24025 [==============================] - 0s 13us/step - loss: 0.0464 - binary_accuracy: 0.9863 - val_loss: 0.0447 - val_binary_accuracy: 0.9867
# Epoch 186/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0471 - binary_accuracy: 0.9864 - val_loss: 0.0497 - val_binary_accuracy: 0.9863
# Epoch 187/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0477 - binary_accuracy: 0.9856 - val_loss: 0.0441 - val_binary_accuracy: 0.9873
# Epoch 188/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0465 - binary_accuracy: 0.9854 - val_loss: 0.0436 - val_binary_accuracy: 0.9870
# Epoch 189/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0468 - binary_accuracy: 0.9859 - val_loss: 0.0446 - val_binary_accuracy: 0.9868
# Epoch 190/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0468 - binary_accuracy: 0.9860 - val_loss: 0.0430 - val_binary_accuracy: 0.9882
# Epoch 191/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0450 - binary_accuracy: 0.9866 - val_loss: 0.0441 - val_binary_accuracy: 0.9873
# Epoch 192/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0465 - binary_accuracy: 0.9858 - val_loss: 0.0444 - val_binary_accuracy: 0.9875
# Epoch 193/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0467 - binary_accuracy: 0.9859 - val_loss: 0.0433 - val_binary_accuracy: 0.9873
# Epoch 194/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0459 - binary_accuracy: 0.9868 - val_loss: 0.0437 - val_binary_accuracy: 0.9868
# Epoch 195/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0460 - binary_accuracy: 0.9862 - val_loss: 0.0434 - val_binary_accuracy: 0.9877
# Epoch 196/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0467 - binary_accuracy: 0.9863 - val_loss: 0.0468 - val_binary_accuracy: 0.9863
# Epoch 197/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0461 - binary_accuracy: 0.9864 - val_loss: 0.0456 - val_binary_accuracy: 0.9870
# Epoch 198/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0470 - binary_accuracy: 0.9852 - val_loss: 0.0436 - val_binary_accuracy: 0.9882
# Epoch 199/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0464 - binary_accuracy: 0.9860 - val_loss: 0.0451 - val_binary_accuracy: 0.9873
# Epoch 200/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0463 - binary_accuracy: 0.9856 - val_loss: 0.0436 - val_binary_accuracy: 0.9870
# Epoch 201/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0465 - binary_accuracy: 0.9863 - val_loss: 0.0460 - val_binary_accuracy: 0.9865
# Epoch 202/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0454 - binary_accuracy: 0.9863 - val_loss: 0.0448 - val_binary_accuracy: 0.9867
# Epoch 203/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0457 - binary_accuracy: 0.9861 - val_loss: 0.0437 - val_binary_accuracy: 0.9873
# Epoch 204/270
# 24025/24025 [==============================] - 0s 9us/step - loss: 0.0453 - binary_accuracy: 0.9863 - val_loss: 0.0486 - val_binary_accuracy: 0.9855
# Epoch 205/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0456 - binary_accuracy: 0.9863 - val_loss: 0.0457 - val_binary_accuracy: 0.9873
# Epoch 206/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0458 - binary_accuracy: 0.9868 - val_loss: 0.0443 - val_binary_accuracy: 0.9867
# Epoch 207/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0450 - binary_accuracy: 0.9866 - val_loss: 0.0437 - val_binary_accuracy: 0.9872
# Epoch 208/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0460 - binary_accuracy: 0.9860 - val_loss: 0.0451 - val_binary_accuracy: 0.9868
# Epoch 209/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0467 - binary_accuracy: 0.9860 - val_loss: 0.0454 - val_binary_accuracy: 0.9873
# Epoch 210/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0463 - binary_accuracy: 0.9866 - val_loss: 0.0447 - val_binary_accuracy: 0.9872
# Epoch 211/270
# 24025/24025 [==============================] - 0s 13us/step - loss: 0.0458 - binary_accuracy: 0.9863 - val_loss: 0.0433 - val_binary_accuracy: 0.9878
# Epoch 212/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0456 - binary_accuracy: 0.9862 - val_loss: 0.0439 - val_binary_accuracy: 0.9873
# Epoch 213/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0465 - binary_accuracy: 0.9862 - val_loss: 0.0438 - val_binary_accuracy: 0.9875
# Epoch 214/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0460 - binary_accuracy: 0.9866 - val_loss: 0.0441 - val_binary_accuracy: 0.9873
# Epoch 215/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0462 - binary_accuracy: 0.9864 - val_loss: 0.0461 - val_binary_accuracy: 0.9868
# Epoch 216/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0454 - binary_accuracy: 0.9861 - val_loss: 0.0452 - val_binary_accuracy: 0.9865
# Epoch 217/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0464 - binary_accuracy: 0.9861 - val_loss: 0.0452 - val_binary_accuracy: 0.9865
# Epoch 218/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0453 - binary_accuracy: 0.9863 - val_loss: 0.0434 - val_binary_accuracy: 0.9872
# Epoch 219/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0455 - binary_accuracy: 0.9863 - val_loss: 0.0443 - val_binary_accuracy: 0.9877
# Epoch 220/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0461 - binary_accuracy: 0.9863 - val_loss: 0.0435 - val_binary_accuracy: 0.9878
# Epoch 221/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0460 - binary_accuracy: 0.9863 - val_loss: 0.0435 - val_binary_accuracy: 0.9877
# Epoch 222/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0460 - binary_accuracy: 0.9863 - val_loss: 0.0431 - val_binary_accuracy: 0.9875
# Epoch 223/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0456 - binary_accuracy: 0.9867 - val_loss: 0.0455 - val_binary_accuracy: 0.9872
# Epoch 224/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0457 - binary_accuracy: 0.9866 - val_loss: 0.0438 - val_binary_accuracy: 0.9870
# Epoch 225/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0450 - binary_accuracy: 0.9863 - val_loss: 0.0470 - val_binary_accuracy: 0.9857
# Epoch 226/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0447 - binary_accuracy: 0.9866 - val_loss: 0.0428 - val_binary_accuracy: 0.9877
# Epoch 227/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0463 - binary_accuracy: 0.9866 - val_loss: 0.0428 - val_binary_accuracy: 0.9882
# Epoch 228/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0452 - binary_accuracy: 0.9860 - val_loss: 0.0446 - val_binary_accuracy: 0.9872
# Epoch 229/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0447 - binary_accuracy: 0.9862 - val_loss: 0.0446 - val_binary_accuracy: 0.9863
# Epoch 230/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0459 - binary_accuracy: 0.9863 - val_loss: 0.0427 - val_binary_accuracy: 0.9870
# Epoch 231/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0453 - binary_accuracy: 0.9863 - val_loss: 0.0456 - val_binary_accuracy: 0.9872
# Epoch 232/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0456 - binary_accuracy: 0.9868 - val_loss: 0.0431 - val_binary_accuracy: 0.9880
# Epoch 233/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0444 - binary_accuracy: 0.9866 - val_loss: 0.0428 - val_binary_accuracy: 0.9878
# Epoch 234/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0450 - binary_accuracy: 0.9861 - val_loss: 0.0430 - val_binary_accuracy: 0.9872
# Epoch 235/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0460 - binary_accuracy: 0.9857 - val_loss: 0.0472 - val_binary_accuracy: 0.9863
# Epoch 236/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0442 - binary_accuracy: 0.9871 - val_loss: 0.0447 - val_binary_accuracy: 0.9873
# Epoch 237/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0456 - binary_accuracy: 0.9863 - val_loss: 0.0433 - val_binary_accuracy: 0.9872
# Epoch 238/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0448 - binary_accuracy: 0.9860 - val_loss: 0.0429 - val_binary_accuracy: 0.9872
# Epoch 239/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0450 - binary_accuracy: 0.9863 - val_loss: 0.0446 - val_binary_accuracy: 0.9873
# Epoch 240/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0454 - binary_accuracy: 0.9860 - val_loss: 0.0439 - val_binary_accuracy: 0.9870
# Epoch 241/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0459 - binary_accuracy: 0.9859 - val_loss: 0.0427 - val_binary_accuracy: 0.9878
# Epoch 242/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0447 - binary_accuracy: 0.9863 - val_loss: 0.0431 - val_binary_accuracy: 0.9870
# Epoch 243/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0457 - binary_accuracy: 0.9863 - val_loss: 0.0427 - val_binary_accuracy: 0.9880
# Epoch 244/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0448 - binary_accuracy: 0.9863 - val_loss: 0.0424 - val_binary_accuracy: 0.9877
# Epoch 245/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0455 - binary_accuracy: 0.9865 - val_loss: 0.0426 - val_binary_accuracy: 0.9883
# Epoch 246/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0448 - binary_accuracy: 0.9863 - val_loss: 0.0434 - val_binary_accuracy: 0.9877
# Epoch 247/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0444 - binary_accuracy: 0.9864 - val_loss: 0.0440 - val_binary_accuracy: 0.9875
# Epoch 248/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0443 - binary_accuracy: 0.9867 - val_loss: 0.0436 - val_binary_accuracy: 0.9875
# Epoch 249/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0448 - binary_accuracy: 0.9859 - val_loss: 0.0473 - val_binary_accuracy: 0.9858
# Epoch 250/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0431 - binary_accuracy: 0.9868 - val_loss: 0.0426 - val_binary_accuracy: 0.9882
# Epoch 251/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0445 - binary_accuracy: 0.9866 - val_loss: 0.0431 - val_binary_accuracy: 0.9872
# Epoch 252/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0449 - binary_accuracy: 0.9869 - val_loss: 0.0437 - val_binary_accuracy: 0.9870
# Epoch 253/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0454 - binary_accuracy: 0.9864 - val_loss: 0.0437 - val_binary_accuracy: 0.9870
# Epoch 254/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0449 - binary_accuracy: 0.9857 - val_loss: 0.0421 - val_binary_accuracy: 0.9875
# Epoch 255/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0446 - binary_accuracy: 0.9868 - val_loss: 0.0462 - val_binary_accuracy: 0.9872
# Epoch 256/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0456 - binary_accuracy: 0.9862 - val_loss: 0.0430 - val_binary_accuracy: 0.9873
# Epoch 257/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0448 - binary_accuracy: 0.9865 - val_loss: 0.0437 - val_binary_accuracy: 0.9868
# Epoch 258/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0448 - binary_accuracy: 0.9865 - val_loss: 0.0428 - val_binary_accuracy: 0.9875
# Epoch 259/270
# 24025/24025 [==============================] - ETA: 0s - loss: 0.0453 - binary_accuracy: 0.986 - 0s 7us/step - loss: 0.0438 - binary_accuracy: 0.9868 - val_loss: 0.0431 - val_binary_accuracy: 0.9872
# Epoch 260/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0444 - binary_accuracy: 0.9868 - val_loss: 0.0473 - val_binary_accuracy: 0.9858
# Epoch 261/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0444 - binary_accuracy: 0.9865 - val_loss: 0.0430 - val_binary_accuracy: 0.9872
# Epoch 262/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0438 - binary_accuracy: 0.9870 - val_loss: 0.0429 - val_binary_accuracy: 0.9873
# Epoch 263/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0442 - binary_accuracy: 0.9868 - val_loss: 0.0431 - val_binary_accuracy: 0.9872
# Epoch 264/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0445 - binary_accuracy: 0.9865 - val_loss: 0.0430 - val_binary_accuracy: 0.9872
# Epoch 265/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0446 - binary_accuracy: 0.9862 - val_loss: 0.0433 - val_binary_accuracy: 0.9868
# Epoch 266/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0446 - binary_accuracy: 0.9865 - val_loss: 0.0426 - val_binary_accuracy: 0.9873
# Epoch 267/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0436 - binary_accuracy: 0.9870 - val_loss: 0.0493 - val_binary_accuracy: 0.9847
# Epoch 268/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0451 - binary_accuracy: 0.9864 - val_loss: 0.0447 - val_binary_accuracy: 0.9868
# Epoch 269/270
# 24025/24025 [==============================] - 0s 7us/step - loss: 0.0448 - binary_accuracy: 0.9865 - val_loss: 0.0434 - val_binary_accuracy: 0.9877
# Epoch 270/270
# 24025/24025 [==============================] - 0s 8us/step - loss: 0.0440 - binary_accuracy: 0.9862 - val_loss: 0.0434 - val_binary_accuracy: 0.9870

# %%
ann.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 26)                702
# _________________________________________________________________
# dense_2 (Dense)              (None, 11)                297
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 11)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 72
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 14
# =================================================================
# Total params: 1,085
# Trainable params: 1,085
# Non-trainable params: 0
# _________________________________________________________________

# %%
scores = ann.evaluate(x_test_ann, y_test_ann, verbose = 0)
print("Test Accuracy (Artificial Neural Network): {}%" .format(scores[1] * 100))
# Out:
# Test Accuracy (Artificial Neural Network): 98.70151281356812%

# %%
scores
# Out:
# [0.043366548380300844, 0.9870151281356812]

# %%
y_pred = ann.predict(x_test_ann)

# Compute confusion matrix
matrix = confusion_matrix(y_test_ann.argmax(axis = 1), y_pred.argmax(axis = 1)) # Building the confusion matrix

# %%
matrix
# Out:
# array([[3883,   69],
#        [   9, 2046]], dtype=int64)

# %%
# Training the model
rf = RandomForestClassifier(n_estimators = 100, class_weight = 'balanced')
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight='balanced',
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=None, oob_score=False,
#                        random_state=None, verbose=0, warm_start=False)

# %%
# Model predictions
y_pred = rf.predict(x_test)
probs = rf.predict_proba(x_test)[:, 1] # Positive class probabilities

# %%
params = {'legend.fontsize': 'small',
         'axes.labelsize': 'x-small',
         'axes.titlesize':'small',
         'xtick.labelsize':'x-small',
         'ytick.labelsize':'x-small'}
pylab.rcParams.update(params)

# %%
# Confusion matrix code adapted from https://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
def plot_confusion_matrix(cm, classes, normalize = False, title = 'Confusion matrix', cmap = plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize = True.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis = 1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    dummy = np.array([[0, 0], [0, 0]])
    plt.figure(figsize = (6, 6))
    plt.imshow(dummy, interpolation = 'nearest', cmap = cmap)
    plt.title(title)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation = 45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment = "center",
                 color = "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()


# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
class_names = ['not mining pool', 'mining pool']
np.set_printoptions(precision = 2)

# Plot confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes = class_names, normalize = False, title = 'Bitcoin Mining Pool Detector using Random Forest - Confusion Matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[3917   35]
#  [   6 2049]]

# %%
# Calculating Accuracy
acc = (cnf_matrix[0][0] + cnf_matrix[1][1]) / (cnf_matrix[0][0] + cnf_matrix[1][1] + cnf_matrix[0][1] + cnf_matrix[1][0])

# %%
print("Test Accuracy (Random Forest Classification): {}%" .format(acc * 100))
# Out:
# Test Accuracy (Random Forest Classification): 99.31746295988015%

# %%
params = {'legend.fontsize': 'small',
         'axes.labelsize': 'small',
         'axes.titlesize':'small',
         'xtick.labelsize':'small',
         'ytick.labelsize':'small'
         }
pylab.rcParams.update(params)

# %%
x_pos = np.arange(len(features.columns))
btc_importances = rf.feature_importances_

inds = np.argsort(btc_importances)[::-1]
btc_importances = btc_importances[inds]
cols = features.columns[inds]
bar_width = .8

# How many features to plot?
n_features = 26
x_pos = x_pos[:n_features][::-1]
btc_importances = btc_importances[:n_features]

# Plot
plt.figure(figsize = (26, 10))
plt.barh(x_pos, btc_importances, bar_width, label = 'BTC model')
plt.yticks(x_pos, cols, rotation = 0, fontsize = 14)
plt.xlabel('feature importance', fontsize = 14)
plt.title('Mining Pool Detector', fontsize = 20)
plt.tight_layout()

# %%
# Data points where model predicts true, but are labelled as false
false_positives = (y_test == False) & (y_pred == True)

# %%
# Subset to test set data only
df_test = df.iloc[indices_test, :]

print('False Positive addresses')

# Subset test set to false positives only
df_test.iloc[false_positives].head(15)
# Out:
# False Positive addresses
#        is_miner                             address  output_month_min  \
# 2112      False  1PHfd3NNxwtD6BQxy2xVQVpjjZ2FJS9GyH        1430438400
# 1692      False  1AFLT4J62CPzKog7r5ZcyQWfeNyQSZ5Z6H        1430438400
# 1676      False  1DYnAL46ksdunqJHUAuMPoEdTq1nBLRPXZ        1435708800
# 553       False  14eUW1v2vUvVFFu5Bb8nQpBWJ63EiU7nX1        1385856000
# 949       False  18nb47rFcmki1Z89x334s19jXkFENAZkWJ        1409529600
# 2167      False  1JgePaoVnbDWVBzuU1uWrgv5XQgzuygQd9        1356998400
# 69        False  18cXogbHgq8JRQAeGbJTPtnhUmPaVAtvXe        1398902400
# 29407     False  13iYbzMn12zVE7T1yVrvNuAXqHPier7buC        1430438400
# 423       False  1Abp5QYRXj3VBe4UvMTwmqrV5V8srpzgKX        1385856000
# 2072      False  1FdAoa3EdCudHLyGAjLVDSb1ucm39VZBuu        1438387200
# 29389     False  1MTm56J6M1jgSLuZhJoG5J8oG6C3zrModo        1306886400
# 29181     False  1Kch5Ed7ZGVU1o3VHG4LzKzoTMi66NC4cW        1446336000
# 64        False  1BopHSXhJ6BvBhTC8b3fFL16eFyJMSzr9p        1427846400
# 651       False  1MpyxKQ23f11XPG76S3uSDTQQHsUcKqh4e        1412121600
# 24        False  1B5rqCmDNQdGw5zGhvXgMNm4dZBNMPQX9Q        1401580800
#
#        output_month_max  input_month_min  input_month_max  output_active_time  \
# 2112         1467331200       1430438400       1467331200            36892800
# 1692         1575158400       1433116800       1575158400           144720000
# 1676         1485907200       1443657600       1485907200            50198400
# 553          1412121600       1388534400       1398902400            26265600
# 949          1462060800       1412121600       1462060800            52531200
# 2167         1393632000       1356998400       1393632000            36633600
# 69           1406851200       1401580800       1409529600             7948800
# 29407        1446336000       1430438400       1446336000            15897600
# 423          1501545600       1385856000       1496275200           115689600
# 2072         1464739200       1438387200       1509494400            26352000
# 29389        1312156800       1306886400       1325376000             5270400
# 29181        1488326400       1446336000       1488326400            41990400
# 64           1454284800       1427846400       1454284800            26438400
# 651          1506816000       1414800000       1506816000            94694400
# 24           1459468800       1401580800       1459468800            57888000
#
#        input_active_time  io_max_lag  io_min_lag  ...  input_active_months  \
# 2112            36892800           0           0  ...                   13
# 1692           142041600           0    -2678400  ...                   13
# 1676            42249600           0    -7948800  ...                   17
# 553             10368000    13219200    -2678400  ...                    5
# 949             49939200           0    -2592000  ...                   13
# 2167            36633600           0           0  ...                   13
# 69               7948800    -2678400    -2678400  ...                    3
# 29407           15897600           0           0  ...                    6
# 423            110419200     5270400           0  ...                   16
# 2072            71107200   -44755200           0  ...                    7
# 29389           18489600   -13219200           0  ...                    3
# 29181           41990400           0           0  ...                    6
# 64              26438400           0           0  ...                    8
# 651             92016000           0    -2678400  ...                    9
# 24              57888000           0           0  ...                   20
#
#        total_tx_input_count total_tx_input_value  mean_tx_input_value  \
# 2112                    195          12271986694   62933265.097435897
# 1692                     47          46748397436  994646753.957446809
# 1676                    537           3235896685    6025878.370577281
# 553                     116            272919882    2352757.603448276
# 949                     149           1007301680    6760413.959731544
# 2167                     71           8989239104  126609001.464788732
# 69                       32            742818382        23213074.4375
# 29407                    25           2876100000            115044000
# 423                      53            176556442    3331253.622641509
# 2072                     51           2810801176   55113748.549019608
# 29389                    25           3090645391         123625815.64
# 29181                    24           1050742213   43780925.541666667
# 64                       62            141715021     2285726.14516129
# 651                      20            146868562            7343428.1
# 24                      257           1756038613    6832835.070038911
#
#        stddev_tx_input_value  total_input_tx mean_monthly_input_value  \
# 2112            1.426318e+08             191       62933265.097435897
# 1692            9.730263e+08              44      994646753.957446809
# 1676            7.306143e+06             298        6025878.370577281
# 553             1.757685e+06              41        2352757.603448276
# 949             6.944110e+06             134        6760413.959731544
# 2167            4.296314e+08              36      126609001.464788732
# 69              5.485185e+07               5            23213074.4375
# 29407           7.848055e+07              24                115044000
# 423             4.812120e+06              29        3331253.622641509
# 2072            9.234522e+07              42       55113748.549019608
# 29389           1.529284e+08              25             123625815.64
# 29181           7.187388e+07              13       43780925.541666667
# 64              8.224732e+06              58         2285726.14516129
# 651             7.437870e+06              12                7343428.1
# 24              7.190229e+06             149        6832835.070038911
#
#        mean_monthly_input_count  mean_output_idle_time  mean_input_idle_time
# 2112                        1.0           1.871262e+05          1.900917e+05
# 1692                        1.0           3.266446e+06          3.519500e+06
# 1676                        1.0           9.090538e+04          1.481556e+05
# 553                         1.0           2.175458e+05          2.981349e+05
# 949                         1.0           4.115836e+05          4.171989e+05
# 2167                        1.0           5.579629e+05          1.203000e+06
# 69                          1.0           2.400983e+05          2.077806e+06
# 29407                       1.0           7.030108e+05          7.028565e+05
# 423                         1.0           2.233183e+06          4.112264e+06
# 2072                        1.0           6.574630e+05          2.291697e+06
# 29389                       1.0           2.264079e+05          7.643538e+05
# 29181                       1.0           1.850516e+06          3.592034e+06
# 64                          1.0           4.139766e+05          4.285299e+05
# 651                         1.0           4.958010e+06          8.331470e+06
# 24                          1.0           2.423020e+05          4.096455e+05
#
# [15 rows x 28 columns]

# %%
index = inds[: -1]
index
# Out:
# array([13,  9, 17,  0,  8, 18, 10,  2,  4,  5, 22, 21, 16,  1, 11, 14, 19,
#         3, 24,  7, 25, 20, 12,  6, 15], dtype=int64)

# %%
data_top = x_train.columns

# %%
xann = pd.DataFrame(data = x_train_ann[0:, 0:], index = [i for i in range(x_train_ann.shape[0])], columns = [str(i) for i in data_top])
xtann = pd.DataFrame(data = x_test_ann[0:, 0:], index = [i for i in range(x_test_ann.shape[0])], columns = [str(i) for i in data_top])
xrf = x_train
xtrf = x_test
i = 1

# %%
ann_acc = [scores[1] * 100]
rf_acc = [acc * 100]
print("{}- All 26 features taken as input:" .format(i))
print("ANN test accuracy = {}%, RF test accuracy = {}%" .format(ann_acc[0], rf_acc[0]))
for x in reversed(index):
    xann = xann.drop(columns = [data_top[x]])	
    xtann = xtann.drop(columns = [data_top[x]])
    xrf = xrf.drop(columns = [data_top[x]])
    xtrf = xtrf.drop(columns = [data_top[x]])
    
    # Creating model
    ann = Sequential()
    ann.add(Dense(26, activation = 'tanh', kernel_initializer = 'glorot_uniform'))
    ann.add(Dense(11, activation = 'tanh'))
    ann.add(Dropout(0.5))
    ann.add(Dense(6, activation = 'tanh'))
    ann.add(Dense(num_classes, activation = 'softmax'))

    rmsprop = optimizers.RMSprop(learn_rate)
    ann.compile(loss = 'binary_crossentropy', optimizer = rmsprop, metrics = ['binary_accuracy']) # Compiling the model

    # Model fitting
    ann.fit(np.array(xann), y_train_ann, batch_size = batch_size, verbose = 0, epochs = epochs)
    scores_ann = ann.evaluate(xtann, y_test_ann, verbose = 0)

    # Training the model
    rf = RandomForestClassifier(n_estimators = 100, class_weight = 'balanced')
    rf.fit(xrf, y_train)

    # Model predictions
    y_pred = rf.predict(xtrf)
    cnf_matrix = confusion_matrix(y_test, y_pred)
    acc = (cnf_matrix[0][0] + cnf_matrix[1][1]) / (cnf_matrix[0][0] + cnf_matrix[1][1] + cnf_matrix[0][1] + cnf_matrix[1][0])
    i += 1
    print("{}- Dropping {}:" .format(i, data_top[x]))
    print("ANN test accuracy = {}%, RF test accuracy = {}%" .format(scores_ann[1] * 100, acc * 100))
    ann_acc.append(scores_ann[1] * 100)
    rf_acc.append(acc * 100)
# Out:
# 1- All 26 features taken as input:
# ANN test accuracy = 98.70151281356812%, RF test accuracy = 99.31746295988015%
# 2- Dropping mean_monthly_output_count:
# ANN test accuracy = 98.70151281356812%, RF test accuracy = 99.30081571499917%
# 3- Dropping io_max_lag:
# ANN test accuracy = 98.73480796813965%, RF test accuracy = 99.30081571499917%
# 4- Dropping stddev_tx_output_value:
# ANN test accuracy = 98.75145554542542%, RF test accuracy = 99.33411020476112%
# 5- Dropping stddev_tx_input_value:
# ANN test accuracy = 98.71816039085388%, RF test accuracy = 99.28416847011819%
# 6- Dropping mean_input_idle_time:
# ANN test accuracy = 98.68486523628235%, RF test accuracy = 99.30081571499917%
# 7- Dropping io_min_lag:
# ANN test accuracy = 98.601633310318%, RF test accuracy = 99.31746295988015%
# 8- Dropping mean_output_idle_time:
# ANN test accuracy = 98.66821765899658%, RF test accuracy = 99.33411020476112%
# 9- Dropping input_month_max:
# ANN test accuracy = 98.80139827728271%, RF test accuracy = 99.30081571499917%
# 10- Dropping mean_tx_input_value:
# ANN test accuracy = 98.6515760421753%, RF test accuracy = 99.25087398035625%
# 11- Dropping mean_monthly_output_value:
# ANN test accuracy = 98.70151281356812%, RF test accuracy = 99.28416847011819%
# 12- Dropping mean_tx_output_value:
# ANN test accuracy = 98.6515760421753%, RF test accuracy = 99.30081571499917%
# 13- Dropping output_month_max:
# ANN test accuracy = 98.66821765899658%, RF test accuracy = 99.28416847011819%
# 14- Dropping input_active_months:
# ANN test accuracy = 98.76810312271118%, RF test accuracy = 99.30081571499917%
# 15- Dropping total_input_tx:
# ANN test accuracy = 98.78475069999695%, RF test accuracy = 99.2175794905943%
# 16- Dropping mean_monthly_input_value:
# ANN test accuracy = 98.68486523628235%, RF test accuracy = 99.20093224571333%
# 17- Dropping input_active_time:
# ANN test accuracy = 98.76810312271118%, RF test accuracy = 99.15099051107042%
# 18- Dropping output_active_time:
# ANN test accuracy = 98.83469343185425%, RF test accuracy = 99.20093224571333%
# 19- Dropping input_month_min:
# ANN test accuracy = 98.78475069999695%, RF test accuracy = 99.20093224571333%
# 20- Dropping total_tx_output_value:
# ANN test accuracy = 98.71816039085388%, RF test accuracy = 99.23422673547529%
# 21- Dropping total_tx_input_value:
# ANN test accuracy = 98.58498573303223%, RF test accuracy = 98.70151489928418%
# 22- Dropping output_active_months:
# ANN test accuracy = 98.51839542388916%, RF test accuracy = 98.35192275678375%
# 23- Dropping output_month_min:
# ANN test accuracy = 94.2067563533783%, RF test accuracy = 93.8904611286832%
# 24- Dropping total_tx_input_count:
# ANN test accuracy = 94.2566990852356%, RF test accuracy = 94.1901115365407%
# 25- Dropping total_tx_output_count:
# ANN test accuracy = 94.28999423980713%, RF test accuracy = 94.14016980189778%
# 26- Dropping total_output_tx:
# ANN test accuracy = 65.78991413116455%, RF test accuracy = 65.78991176960213%

# %%
# Create plots with pre-defined labels
f = plt.figure(figsize = (10, 10))
ax = f.add_subplot(121)
t = list(np.arange(1., 27., 1))
t.reverse()
ax.plot(t, rf_acc, 'r-', label = 'Random Forest')
ax.plot(t, ann_acc, 'b--', label = 'Artificial Neural Network')

legend = ax.legend(loc = 'lower right', shadow = True, fontsize = 'x-small')

# Put a nicer background color on the legend.
legend.get_frame().set_facecolor('C6')
plt.ylabel('Test Accuracy (%)')
plt.xlabel('Number of features')
plt.title('RF vs ANN (Accuracy Comparison)')
plt.show()

# %%
# Fitting Naive Bayes to the Training set
nb = GaussianNB()
nb.fit(x_train, y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
# Predicting the Test set results
y_pred = nb.predict(x_test)

# %%
# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
class_names = ['not mining pool', 'mining pool']
np.set_printoptions(precision = 3)

# Plot confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes = class_names, normalize = False, title = 'Bitcoin Mining Pool Detector using Naive Bayes - Confusion Matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[3358  594]
#  [  21 2034]]

# %%
# Calculating Accuracy
acc = (cnf_matrix[0][0] + cnf_matrix[1][1]) / (cnf_matrix[0][0] + cnf_matrix[1][1] + cnf_matrix[0][1] + cnf_matrix[1][0])
print("Test Accuracy (Naive Bayes Classification): {}%" .format(acc * 100))
# Out:
# Test Accuracy (Naive Bayes Classification): 89.7619443982021%
